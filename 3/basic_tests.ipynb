# %%
import networks as net
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
MSD10_LR1=net.SimpleModel(layers=2,num_hidden=200,lr=1e-5)
MSD10_LR1.run_session()
MSD10_LR2=net.SimpleModel(layers=2,num_hidden=200,lr=1e-4)
MSD10_LR2.run_session()
MSD10_LR3=net.SimpleModel(layers=2,num_hidden=200,lr=1e-3)
MSD10_LR3.run_session()
# Out:
# End of epoch 01: err(train)=2.23 acc(train)=0.22 run_time=6.02s | err(valid)=1.99 acc(valid)=0.29
# End of epoch 02: err(train)=1.87 acc(train)=0.33 run_time=6.09s | err(valid)=1.85 acc(valid)=0.34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ea8e06048d09> in <module>()
#       1 MSD10_LR1=net.SimpleModel(layers=2,num_hidden=200,lr=1e-5)
# ----> 2 MSD10_LR1.run_session()
#       3 MSD10_LR2=net.SimpleModel(layers=2,num_hidden=200,lr=1e-4)
#       4 MSD10_LR2.run_session()
#       5 MSD10_LR3=net.SimpleModel(layers=2,num_hidden=200,lr=1e-3)
#
# /afs/inf.ed.ac.uk/user/s16/s1666320/mymlp/3/networks.py in run_session(self)
#      59                 _, batch_error, batch_acc = sess.run(
#      60                     [self.train_step, self.error, self.accuracy],
# ---> 61                     feed_dict={self.inputs: input_batch, self.targets: target_batch})
# ...

# %%
MSD25_LR1=net.SimpleModel(layers=2,num_hidden=200,lr=1e-5,provider=1)
MSD25_LR1.run_session()
MSD25_LR2=net.SimpleModel(layers=2,num_hidden=200,lr=1e-4,provider=1)
MSD25_LR2.run_session()
MSD25_LR3=net.SimpleModel(layers=2,num_hidden=200,lr=1e-3,provider=1)
MSD25_LR3.run_session()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-39bddf0e72be> in <module>()
# ----> 1 MSD25_LR1=net.SimpleModel(layers=2,num_hidden=200,lr=1e-5,provider=1)
#       2 MSD25_LR1.run_session()
#       3 MSD25_LR2=net.SimpleModel(layers=2,num_hidden=200,lr=1e-4,provider=1)
#       4 MSD25_LR2.run_session()
#       5 MSD25_LR3=net.SimpleModel(layers=2,num_hidden=200,lr=1e-3,provider=1)
#
# /afs/inf.ed.ac.uk/user/s16/s1666320/mymlp/3/networks.py in __init__(self, layers, num_hidden, lr, num_epochs, provider, out)
#     129
#     130     def __init__(self,layers=1,num_hidden=200,lr=1e-3,num_epochs=10,provider=0,out=1):
# --> 131         super(SimpleModel).__init__(layers,num_hidden,lr,num_epochs,provider,out)
#     132         self.learning_functions()
#     133
#
# TypeError: super() takes at most 2 arguments (6 given)

# %%
units = [100,200,300]
lays = [1,2,3]
MSD10_L_HU = []
for k in range(len(lays)):
    MSD_list = []
    for j in range(len(units)):
        MSD_temp = net.SimpleModel(layers=lays[k],num_hidden=units[j],lr=1e-3,num_epochs=10,out=1)
        MSD_temp.run_session()
        MSD_list.append(MSD_temp)
    MSD10_L_HU.append(MSD_list)
# Out:
# End of epoch 01: err(train)=1.96 acc(train)=0.39 run_time=3.97s | err(valid)=1.68 acc(valid)=0.44
# End of epoch 02: err(train)=1.25 acc(train)=0.57 run_time=4.05s | err(valid)=1.73 acc(valid)=0.43
# End of epoch 03: err(train)=1.02 acc(train)=0.65 run_time=3.75s | err(valid)=1.87 acc(valid)=0.43
# End of epoch 04: err(train)=0.80 acc(train)=0.73 run_time=3.78s | err(valid)=2.14 acc(valid)=0.40
# End of epoch 05: err(train)=0.59 acc(train)=0.81 run_time=3.76s | err(valid)=2.44 acc(valid)=0.42
# End of epoch 06: err(train)=0.42 acc(train)=0.86 run_time=3.77s | err(valid)=2.78 acc(valid)=0.40
# End of epoch 07: err(train)=0.30 acc(train)=0.90 run_time=3.86s | err(valid)=3.14 acc(valid)=0.40
# End of epoch 08: err(train)=0.22 acc(train)=0.93 run_time=3.75s | err(valid)=3.54 acc(valid)=0.39
# End of epoch 09: err(train)=0.19 acc(train)=0.94 run_time=3.92s | err(valid)=3.85 acc(valid)=0.40
# End of epoch 10: err(train)=0.17 acc(train)=0.94 run_time=4.01s | err(valid)=4.16 acc(valid)=0.40
# ...

# %%
MSD25_L_HU = []
for k in range(len(lays)):
    MSD_list = []
    for j in range(len(units)):
        MSD_temp = net.SimpleModel(layers=lays[k],num_hidden=units[j],num_epochs=10,lr=1e-3,provider=1)
        MSD_temp.run_session()
        MSD_list.append(MSD_temp)
    MSD25_L_HU.append(MSD_list)
# Out:
# End of epoch 01: err(train)=3.29 acc(train)=0.14 run_time=5.68s | err(valid)=2.97 acc(valid)=0.16
# End of epoch 02: err(train)=2.34 acc(train)=0.30 run_time=4.27s | err(valid)=3.03 acc(valid)=0.16
# End of epoch 03: err(train)=2.01 acc(train)=0.40 run_time=4.06s | err(valid)=3.26 acc(valid)=0.16
# End of epoch 04: err(train)=1.74 acc(train)=0.48 run_time=4.20s | err(valid)=3.54 acc(valid)=0.15
# End of epoch 05: err(train)=1.47 acc(train)=0.56 run_time=5.16s | err(valid)=3.91 acc(valid)=0.14
# End of epoch 06: err(train)=1.21 acc(train)=0.63 run_time=4.71s | err(valid)=4.29 acc(valid)=0.14
# End of epoch 07: err(train)=0.98 acc(train)=0.70 run_time=4.35s | err(valid)=4.81 acc(valid)=0.13
# End of epoch 08: err(train)=0.79 acc(train)=0.76 run_time=3.97s | err(valid)=5.32 acc(valid)=0.13
# End of epoch 09: err(train)=0.63 acc(train)=0.80 run_time=4.21s | err(valid)=5.84 acc(valid)=0.13
# End of epoch 10: err(train)=0.50 acc(train)=0.84 run_time=4.08s | err(valid)=6.44 acc(valid)=0.13
# ...

# %%
MSD10_L_HUPlots = net.MultiPlot(MSD10_L_HU,['hidden units','layers'])
MSD10_L_HUPlots.save('MSD10_L_HU')
MSD10_L_HUPlots.time_heat(lays,units)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-f201e508c658> in <module>()
# ----> 1 MSD10_L_HUPlots = net.MultiPlot(MSD10_L_HU,['hidden units','layers'])
#       2 MSD10_L_HUPlots.save('MSD10_L_HU')
#       3 MSD10_L_HUPlots.time_heat(lays,units)
#
# NameError: name 'MSD10_L_HU' is not defined

# %%
MSD25_L_HUPlots = net.MultiPlot(MSD25_L_HU,['hidden units','layers'])
MSD25_L_HUPlots.save('MSD25_L_HU')
MSD25_L_HUPlots.time_heat(lays,units)

# %%
MSD25_L_HUPlots.time_heat(lays,units)

# %%
MSD10_L_HUPlots.err_heat(lays,units)

# %%
MSD25_L_HUPlots.err_heat(lays,units)

# %%
MSD10_L_HUPlots.acc_heat(lays,units)

# %%
MSD25_L_HUPlots.acc_heat(lays,units)

# %%
meth = ['L1','L2']
rcs = [1e-3,1e-2]
labels = ['lambda','loss']
MSD10_reg = []
for k in range(len(meth)):
    MSD_list = []
    for j in range(len(rcs)):
        MSD_temp = net.RegModel(layers=2,num_hidden=200,num_epochs=40,reg=k,rc=rcs[j])
        MSD_temp.run_session()
        MSD_list.append(MSD_temp)
    MSD10_reg.append(MSD_list)
# Out:
# End of epoch 01: err(train)=7.45 acc(train)=0.42 run_time=19.25s | err(valid)=2.66 acc(valid)=0.42
# End of epoch 02: err(train)=2.35 acc(train)=0.44 run_time=18.34s | err(valid)=2.22 acc(valid)=0.44
# End of epoch 03: err(train)=2.16 acc(train)=0.46 run_time=18.28s | err(valid)=2.15 acc(valid)=0.45
# End of epoch 04: err(train)=2.11 acc(train)=0.46 run_time=18.67s | err(valid)=2.13 acc(valid)=0.45
# End of epoch 05: err(train)=2.09 acc(train)=0.47 run_time=18.79s | err(valid)=2.12 acc(valid)=0.45
# End of epoch 06: err(train)=2.07 acc(train)=0.46 run_time=18.28s | err(valid)=2.10 acc(valid)=0.45
# End of epoch 07: err(train)=2.06 acc(train)=0.47 run_time=18.78s | err(valid)=2.09 acc(valid)=0.45
# End of epoch 08: err(train)=2.05 acc(train)=0.47 run_time=18.91s | err(valid)=2.08 acc(valid)=0.45
# End of epoch 09: err(train)=2.04 acc(train)=0.47 run_time=18.90s | err(valid)=2.09 acc(valid)=0.45
# ...

# %%
MSD10_regPlots = net.MultiPlot(MSD10_reg,labels)

# %%
MSD10_regPlots.save('MSD10_reg')

# %%
MSD10_regPlots.err_grid()
MSD10_regPlots.acc_grid()

# %%
MSD10_regPlots.time_heat(meth,rcs)

# %%
MSD10_regPlots.acc_heat(meth,rcs)

# %%
MSD10_regPlots.err_heat(meth,rcs)

# %%
MSD25_reg = []
for k in range(len(meth)):
    MSD_list = []
    for j in range(len(rcs)):
        MSD_temp = net.RegModel(layers=2,num_hidden=200,num_epochs=20,reg=k,rc=rcs[j],provider=1)
        MSD_temp.run_session()
        MSD_list.append(MSD_temp)
    MSD25_reg.append(MSD_list)
# Out:
# End of epoch 01: err(train)=11.74 acc(train)=0.17 run_time=29.79s | err(valid)=4.03 acc(valid)=0.17
# End of epoch 02: err(train)=3.74 acc(train)=0.18 run_time=33.66s | err(valid)=3.64 acc(valid)=0.18
# End of epoch 03: err(train)=3.59 acc(train)=0.19 run_time=32.46s | err(valid)=3.59 acc(valid)=0.18
# End of epoch 04: err(train)=3.55 acc(train)=0.19 run_time=32.34s | err(valid)=3.57 acc(valid)=0.19
# End of epoch 05: err(train)=3.54 acc(train)=0.20 run_time=32.43s | err(valid)=3.56 acc(valid)=0.19
# End of epoch 06: err(train)=3.52 acc(train)=0.20 run_time=31.78s | err(valid)=3.56 acc(valid)=0.18
# End of epoch 07: err(train)=3.51 acc(train)=0.20 run_time=32.08s | err(valid)=3.54 acc(valid)=0.19
# End of epoch 08: err(train)=3.51 acc(train)=0.20 run_time=32.62s | err(valid)=3.54 acc(valid)=0.19
# End of epoch 09: err(train)=3.50 acc(train)=0.20 run_time=30.91s | err(valid)=3.54 acc(valid)=0.19
# ...

# %%
MSD25_regPlots = net.MultiPlot(MSD25_reg,labels)

# %%
MSD25_regPlots.save('MSD25_reg')

# %%
MSD25_regPlots.err_grid()
MSD25_regPlots.acc_grid()

# %%
MSD25_regPlots.time_heat(meth,rcs)

# %%
MSD25_regPlots.acc_heat(meth,rcs)

# %%
MSD25_regPlots.err_heat(meth,rcs)

# %%
lrs = [1e-4,1e-3]
stds = [0.25,0.05]
fraction = 0.20
labels = ['learning rate','noise level (std)']
MSD10_noisy = []

# %%
for k in range(2):
    MSD_list = []
    MSD_temp = net.NoisyRegModel(num_epochs=30,reg=1,rc=1e-2,lr=lrs[0],fraction=fraction,std=stds[k])
    MSD_temp.run_session()
    MSD_list.append(MSD_temp)
    MSD_temp = net.NoisyRegModel(num_epochs=30,reg=1,rc=1e-2,lr=lrs[1],fraction=fraction,std=stds[k])
    MSD_temp.run_session()
    MSD_list.append(MSD_temp)
    MSD10_noisy.append(MSD_list)
MSD10_noisyPlots = net.MultiPlot(MSD10_noisy,labels)
MSD10_noisyPlots.save('MSD10_noisy')
# Out:
# End of epoch 01: err(train)=20.78 acc(train)=0.36 run_time=42.54s | err(valid)=7.86 acc(valid)=0.39
# End of epoch 02: err(train)=5.15 acc(train)=0.51 run_time=79.23s | err(valid)=4.19 acc(valid)=0.41
# End of epoch 03: err(train)=3.22 acc(train)=0.60 run_time=96.42s | err(valid)=3.41 acc(valid)=0.42
# End of epoch 04: err(train)=2.60 acc(train)=0.67 run_time=99.51s | err(valid)=3.04 acc(valid)=0.44
# End of epoch 05: err(train)=2.22 acc(train)=0.71 run_time=105.10s | err(valid)=2.79 acc(valid)=0.44
# End of epoch 06: err(train)=1.94 acc(train)=0.75 run_time=97.80s | err(valid)=2.60 acc(valid)=0.45
# End of epoch 07: err(train)=1.72 acc(train)=0.77 run_time=91.46s | err(valid)=2.46 acc(valid)=0.45
# End of epoch 08: err(train)=1.56 acc(train)=0.80 run_time=87.66s | err(valid)=2.36 acc(valid)=0.45
# End of epoch 09: err(train)=1.43 acc(train)=0.81 run_time=87.16s | err(valid)=2.29 acc(valid)=0.45
# ...

# %%
MSD10_noisyPlots = net.MultiPlot(MSD10_noisy,labels)

# %%
MSD10_noisyPlots.save('MSD10_noisy')

# %%
MSD10_noisyPlots.err_grid()
MSD10_noisyPlots.acc_grid()

# %%
MSD10_noisyPlots.time_heat(stds,lrs)

# %%
MSD10_noisyPlots.acc_heat(stds,lrs)

# %%
MSD10_noisyPlots.err_heat(stds,lrs)

# %%
fraction = 0.2
MSD10_noisy_ext = net.DropOutRegModel(num_epochs=15,reg=1,rc=1e-2,lr=1e-3,fraction=fraction)
MSD10_noisy_ext.run_session()
# Out:
# End of epoch 01: err(train)=3.69 acc(train)=0.43 run_time=27.70s | err(valid)=2.23 acc(valid)=0.46
# End of epoch 02: err(train)=1.86 acc(train)=0.53 run_time=41.28s | err(valid)=1.96 acc(valid)=0.46
# End of epoch 03: err(train)=1.77 acc(train)=0.53 run_time=50.60s | err(valid)=1.90 acc(valid)=0.46
# End of epoch 04: err(train)=1.75 acc(train)=0.52 run_time=51.72s | err(valid)=1.90 acc(valid)=0.46
# End of epoch 05: err(train)=1.72 acc(train)=0.53 run_time=51.97s | err(valid)=1.88 acc(valid)=0.47
# End of epoch 06: err(train)=1.71 acc(train)=0.53 run_time=52.21s | err(valid)=1.85 acc(valid)=0.48
# End of epoch 07: err(train)=1.69 acc(train)=0.54 run_time=53.14s | err(valid)=1.86 acc(valid)=0.47
# End of epoch 08: err(train)=1.69 acc(train)=0.54 run_time=60.56s | err(valid)=1.87 acc(valid)=0.47
# End of epoch 09: err(train)=1.68 acc(train)=0.54 run_time=54.04s | err(valid)=1.88 acc(valid)=0.47
# ...

# %%
fraction = 0.2
MSD25_noisy_ext = net.DropOutRegModel(num_epochs=15,reg=1,rc=1e-2,lr=1e-3,fraction=fraction,provider=1)
MSD25_noisy_ext.run_session()
# Out:
# End of epoch 01: err(train)=5.15 acc(train)=0.19 run_time=29.59s | err(valid)=3.64 acc(valid)=0.17
# End of epoch 02: err(train)=3.07 acc(train)=0.30 run_time=48.46s | err(valid)=3.27 acc(valid)=0.19
# End of epoch 03: err(train)=2.96 acc(train)=0.29 run_time=59.97s | err(valid)=3.22 acc(valid)=0.19
# End of epoch 04: err(train)=2.94 acc(train)=0.28 run_time=61.45s | err(valid)=3.14 acc(valid)=0.20
# End of epoch 05: err(train)=2.93 acc(train)=0.27 run_time=60.62s | err(valid)=3.10 acc(valid)=0.20
# End of epoch 06: err(train)=2.90 acc(train)=0.27 run_time=64.22s | err(valid)=3.10 acc(valid)=0.20
# End of epoch 07: err(train)=2.89 acc(train)=0.27 run_time=61.78s | err(valid)=3.11 acc(valid)=0.20
# End of epoch 08: err(train)=2.88 acc(train)=0.27 run_time=62.12s | err(valid)=3.08 acc(valid)=0.20
# End of epoch 09: err(train)=2.87 acc(train)=0.28 run_time=65.65s | err(valid)=3.09 acc(valid)=0.19
# ...

# %%
MSD25_noisyPlots = net.MultiPlot(MSD125_noisy,labels)

# %%
fraction = 0.2
MSD25_noisy = []
for k in range(2):
    MSD_list = []
    MSD_temp = net.NoisyRegModel(num_epochs=40,reg=1,rc=1e-2,lr=lrs[0],provider=1,fraction=fraction,std=stds[k])
    MSD_temp.run_session()
    MSD_list.append(MSD_temp)
    MSD_temp = net.NoisyRegModel(num_epochs=40,reg=1,rc=1e-2,lr=lrs[1],provider=1,fraction=fraction,std=stds[k])
    MSD_temp.run_session()
    MSD_list.append(MSD_temp)
    MSD25_noisy.append(MSD_list)
MSD25_noisyPlots = net.MultiPlot(MSD25_noisy,labels)
MSD25_noisyPlots.save('MSD25_noisy')
# Out:
# End of epoch 01: err(train)=6.34 acc(train)=0.13 run_time=15.43s | err(valid)=5.84 acc(valid)=0.14
# End of epoch 02: err(train)=5.09 acc(train)=0.25 run_time=19.31s | err(valid)=5.24 acc(valid)=0.16
# End of epoch 03: err(train)=4.35 acc(train)=0.35 run_time=18.34s | err(valid)=4.82 acc(valid)=0.16
# End of epoch 04: err(train)=3.82 acc(train)=0.42 run_time=18.11s | err(valid)=4.50 acc(valid)=0.17
# End of epoch 05: err(train)=3.42 acc(train)=0.48 run_time=18.09s | err(valid)=4.27 acc(valid)=0.17
# End of epoch 06: err(train)=3.12 acc(train)=0.53 run_time=18.65s | err(valid)=4.09 acc(valid)=0.17
# End of epoch 07: err(train)=2.88 acc(train)=0.56 run_time=18.96s | err(valid)=3.96 acc(valid)=0.17
# End of epoch 08: err(train)=2.70 acc(train)=0.59 run_time=18.34s | err(valid)=3.87 acc(valid)=0.18
# End of epoch 09: err(train)=2.55 acc(train)=0.61 run_time=18.35s | err(valid)=3.81 acc(valid)=0.17
# ...

# %%
MSD25_noisyPlots.save('MSD25_noisy')

# %%
MSD25_noisyPlots.err_grid()
MSD25_noisyPlots.acc_grid()

# %%
MSD25_noisyPlots.time_heat(stds,lrs)

# %%
MSD25_noisyPlots.acc_heat(stds,lrs)

# %%
MSD25_noisyPlots.err_heat(stds,lrs)
