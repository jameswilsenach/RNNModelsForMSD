# %%
import networks as net
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
MSD10_LY1=net.SimpleSimulation(1)
MSD10_LY1.run_session()
MSD10_LY2=net.SimpleSimulation(2)
MSD10_LY2.run_session()
MSD10_LY3=net.SimpleSimulation(3)
MSD10_LY3.run_session()
# Out:
# End of epoch 01: err(train)=2.15 acc(train)=0.34 run_time=6.42s | err(valid)=1.93 acc(valid)=0.37
# End of epoch 02: err(train)=1.54 acc(train)=0.47 run_time=6.49s | err(valid)=1.84 acc(valid)=0.40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-721ebf341eac> in <module>()
#       1 MSD10_LY1=net.SimpleSimulation(1)
# ----> 2 MSD10_LY1.run_session()
#       3 MSD10_LY2=net.SimpleSimulation(2)
#       4 MSD10_LY2.run_session()
#       5 MSD10_LY3=net.SimpleSimulation(3)
#
# /home/james/my_mlp/3/networks.py in run_session(self)
#      53                 _, batch_error, batch_acc = sess.run(
#      54                     [self.train_step, self.error, self.accuracy],
# ---> 55                     feed_dict={self.inputs: input_batch, self.targets: target_batch})
#      56                 running_error += batch_error
# ...

# %%
MSD10_NN1=net.SimpleSimulation(layers=2,num_hidden=100)
MSD10_NN1.run_session()
MSD10_NN2=net.SimpleSimulation(layers=2,num_hidden=200)
MSD10_NN2.run_session()
MSD10_NN3=net.SimpleSimulation(layers=2,num_hidden=300)
MSD10_NN3.run_session()
# Out:
# End of epoch 01: err(train)=1.85 acc(train)=0.34 run_time=4.04s | err(valid)=1.68 acc(valid)=0.41
# End of epoch 02: err(train)=1.53 acc(train)=0.46 run_time=4.06s | err(valid)=1.63 acc(valid)=0.43
# End of epoch 03: err(train)=1.39 acc(train)=0.52 run_time=4.12s | err(valid)=1.61 acc(valid)=0.44
# End of epoch 04: err(train)=1.26 acc(train)=0.57 run_time=4.16s | err(valid)=1.62 acc(valid)=0.44
# End of epoch 05: err(train)=1.15 acc(train)=0.61 run_time=4.16s | err(valid)=1.64 acc(valid)=0.44
# End of epoch 06: err(train)=1.03 acc(train)=0.66 run_time=4.16s | err(valid)=1.67 acc(valid)=0.43
# End of epoch 07: err(train)=0.93 acc(train)=0.70 run_time=4.16s | err(valid)=1.72 acc(valid)=0.43
# End of epoch 08: err(train)=0.82 acc(train)=0.75 run_time=4.15s | err(valid)=1.79 acc(valid)=0.42
# End of epoch 09: err(train)=0.72 acc(train)=0.79 run_time=4.17s | err(valid)=1.87 acc(valid)=0.42
# End of epoch 10: err(train)=0.62 acc(train)=0.83 run_time=4.16s | err(valid)=1.95 acc(valid)=0.41
# ...

# %%
MSD10_LR1=net.SimpleSimulation(layers=2,num_hidden=200,lr=1e-5)
MSD10_LR1.run_session()
MSD10_LR2=net.SimpleSimulation(layers=2,num_hidden=200,lr=1e-4)
MSD10_LR2.run_session()
MSD10_LR3=net.SimpleSimulation(layers=2,num_hidden=200,lr=1e-3)
MSD10_LR3.run_session()
# Out:
# End of epoch 01: err(train)=1.77 acc(train)=0.37 run_time=11.00s | err(valid)=1.63 acc(valid)=0.42
# End of epoch 02: err(train)=1.43 acc(train)=0.50 run_time=11.02s | err(valid)=1.59 acc(valid)=0.44
# End of epoch 03: err(train)=1.22 acc(train)=0.58 run_time=11.00s | err(valid)=1.60 acc(valid)=0.44
# End of epoch 04: err(train)=1.03 acc(train)=0.66 run_time=11.11s | err(valid)=1.64 acc(valid)=0.44
# End of epoch 05: err(train)=0.84 acc(train)=0.74 run_time=11.03s | err(valid)=1.70 acc(valid)=0.43
# End of epoch 06: err(train)=0.66 acc(train)=0.81 run_time=11.36s | err(valid)=1.80 acc(valid)=0.43
# End of epoch 07: err(train)=0.49 acc(train)=0.88 run_time=11.09s | err(valid)=1.94 acc(valid)=0.42
# End of epoch 08: err(train)=0.34 acc(train)=0.93 run_time=11.06s | err(valid)=2.11 acc(valid)=0.42
# End of epoch 09: err(train)=0.22 acc(train)=0.96 run_time=11.07s | err(valid)=2.31 acc(valid)=0.41
# ...

# %%
MSD25_LY1=net.SimpleSimulation(1,provider=1)
MSD25_LY1.run_session()
MSD25_LY2=net.SimpleSimulation(2,provider=1)
MSD25_LY2.run_session()
MSD25_LY3=net.SimpleSimulation(3,provider=1)
MSD25_LY3.run_session()
# Out:
# End of epoch 01: err(train)=3.49 acc(train)=0.12 run_time=7.06s | err(valid)=3.26 acc(valid)=0.14
# End of epoch 02: err(train)=2.79 acc(train)=0.21 run_time=6.68s | err(valid)=3.15 acc(valid)=0.15
# End of epoch 03: err(train)=2.42 acc(train)=0.29 run_time=6.66s | err(valid)=3.12 acc(valid)=0.15
# End of epoch 04: err(train)=2.16 acc(train)=0.37 run_time=6.58s | err(valid)=3.11 acc(valid)=0.15
# End of epoch 05: err(train)=1.94 acc(train)=0.44 run_time=6.77s | err(valid)=3.14 acc(valid)=0.15
# End of epoch 06: err(train)=1.75 acc(train)=0.50 run_time=6.77s | err(valid)=3.17 acc(valid)=0.15
# End of epoch 07: err(train)=1.58 acc(train)=0.56 run_time=7.05s | err(valid)=3.21 acc(valid)=0.15
# End of epoch 08: err(train)=1.43 acc(train)=0.62 run_time=7.01s | err(valid)=3.27 acc(valid)=0.15
# End of epoch 09: err(train)=1.29 acc(train)=0.67 run_time=8.44s | err(valid)=3.34 acc(valid)=0.15
# End of epoch 10: err(train)=1.15 acc(train)=0.72 run_time=9.90s | err(valid)=3.40 acc(valid)=0.15
# ...

# %%
MSD25_NN1=net.SimpleSimulation(layers=2,num_hidden=100,provider=1)
MSD25_NN1.run_session()
MSD25_NN2=net.SimpleSimulation(layers=2,num_hidden=200,provider=1)
MSD25_NN2.run_session()
MSD25_NN3=net.SimpleSimulation(layers=2,num_hidden=300,provider=1)
MSD25_NN3.run_session()
# Out:
# End of epoch 01: err(train)=3.02 acc(train)=0.12 run_time=7.39s | err(valid)=2.84 acc(valid)=0.15
# End of epoch 02: err(train)=2.68 acc(train)=0.19 run_time=6.00s | err(valid)=2.78 acc(valid)=0.17
# End of epoch 03: err(train)=2.52 acc(train)=0.24 run_time=5.81s | err(valid)=2.77 acc(valid)=0.17
# End of epoch 04: err(train)=2.39 acc(train)=0.28 run_time=5.84s | err(valid)=2.78 acc(valid)=0.17
# End of epoch 05: err(train)=2.27 acc(train)=0.32 run_time=6.18s | err(valid)=2.80 acc(valid)=0.17
# End of epoch 06: err(train)=2.15 acc(train)=0.36 run_time=6.13s | err(valid)=2.84 acc(valid)=0.17
# End of epoch 07: err(train)=2.03 acc(train)=0.40 run_time=6.51s | err(valid)=2.88 acc(valid)=0.17
# End of epoch 08: err(train)=1.92 acc(train)=0.44 run_time=6.11s | err(valid)=2.93 acc(valid)=0.17
# End of epoch 09: err(train)=1.80 acc(train)=0.48 run_time=6.25s | err(valid)=3.01 acc(valid)=0.16
# End of epoch 10: err(train)=1.69 acc(train)=0.51 run_time=6.21s | err(valid)=3.07 acc(valid)=0.16
# ...

# %%
MSD25_LR1=net.SimpleSimulation(layers=2,num_hidden=200,lr=1e-5,provider=1)
MSD25_LR1.run_session()
MSD25_LR2=net.SimpleSimulation(layers=2,num_hidden=200,lr=1e-4,provider=1)
MSD25_LR2.run_session()
MSD25_LR3=net.SimpleSimulation(layers=2,num_hidden=200,lr=1e-3,provider=1)
MSD25_LR3.run_session()
# Out:
# End of epoch 01: err(train)=2.94 acc(train)=0.14 run_time=12.14s | err(valid)=2.80 acc(valid)=0.16
# End of epoch 02: err(train)=2.57 acc(train)=0.23 run_time=10.41s | err(valid)=2.77 acc(valid)=0.17
# End of epoch 03: err(train)=2.35 acc(train)=0.30 run_time=11.01s | err(valid)=2.78 acc(valid)=0.17
# End of epoch 04: err(train)=2.14 acc(train)=0.37 run_time=9.90s | err(valid)=2.82 acc(valid)=0.17
# End of epoch 05: err(train)=1.92 acc(train)=0.44 run_time=9.85s | err(valid)=2.90 acc(valid)=0.17
# End of epoch 06: err(train)=1.71 acc(train)=0.52 run_time=11.01s | err(valid)=2.99 acc(valid)=0.16
# End of epoch 07: err(train)=1.49 acc(train)=0.59 run_time=11.15s | err(valid)=3.10 acc(valid)=0.16
# End of epoch 08: err(train)=1.28 acc(train)=0.66 run_time=11.15s | err(valid)=3.25 acc(valid)=0.16
# End of epoch 09: err(train)=1.08 acc(train)=0.73 run_time=11.07s | err(valid)=3.42 acc(valid)=0.15
# ...

# %%
MSD10L2_2=net.RegSimulation(layers=2,num_epochs=30,rc=1e-2)
MSD10L2_2.run_session()
MSD10L2_1=net.RegSimulation(layers=2,num_epochs=30,rc=1e-1)
MSD10L2_1.run_session()
# Out:
# End of epoch 01: err(train)=14.24 acc(train)=0.37 run_time=36.75s | err(valid)=6.71 acc(valid)=0.43
# End of epoch 02: err(train)=5.58 acc(train)=0.50 run_time=66.25s | err(valid)=4.99 acc(valid)=0.45
# End of epoch 03: err(train)=4.28 acc(train)=0.55 run_time=98.49s | err(valid)=4.08 acc(valid)=0.46
# End of epoch 04: err(train)=3.46 acc(train)=0.60 run_time=109.24s | err(valid)=3.51 acc(valid)=0.46
# End of epoch 05: err(train)=2.90 acc(train)=0.64 run_time=109.18s | err(valid)=3.16 acc(valid)=0.47
# End of epoch 06: err(train)=2.49 acc(train)=0.69 run_time=101.41s | err(valid)=2.97 acc(valid)=0.46
# End of epoch 07: err(train)=2.17 acc(train)=0.74 run_time=94.56s | err(valid)=2.86 acc(valid)=0.46
# End of epoch 08: err(train)=1.90 acc(train)=0.79 run_time=92.32s | err(valid)=2.85 acc(valid)=0.45
# End of epoch 09: err(train)=1.68 acc(train)=0.84 run_time=92.66s | err(valid)=2.86 acc(valid)=0.45
# ...

# %%
units = [100,200,300]
lays = [1,2,3]
MSD_L_HU = []
for k in range(len(lays)):
    MSD_list = []
    for j in range(len(units)):
        MSD_temp = net.SimpleSimulation(layers=lays[k],num_hidden=units[j],num_epochs=10,out=0)
        MSD_temp.run_session()
        MSD_list.append(MSD_temp)
    MSD_L_HU.append(MSD_list)

# %%
MSDsims=net.MultiPlot(MSD_L_HU)
MSDsims.err_grid()

# %%
MSDsims.time_heat(lays,units)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-2a57fdd302ce> in <module>()
# ----> 1 MSDsims.time_heat(lays,units)
#
# /home/james/my_mlp/3/networks.py in time_heat(self, rs, cs)
#     212                 times[k,j]=self.sims[k][j].avg_time
#     213         times = pd.DataFrame(times)
# --> 214         times = pd.DataFrame(times,index=np.str(rs))
#     215         times = pd.DataFrame(times,columns=np.str(cs))
#     216         fig = sns.heatmap(times, annot=True, fmt="d")
#
# /home/james/miniconda3/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     262         if isinstance(data, BlockManager):
#     263             mgr = self._init_mgr(data, axes=dict(index=index, columns=columns),
# --> 264                                  dtype=dtype, copy=copy)
#     265         elif isinstance(data, dict):
# ...
