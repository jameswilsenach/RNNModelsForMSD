# %%
import rnn_networks as net
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
MSD10_basic=net.RNN_Model(num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_basic.run_session()
# Out:
# End of epoch 01: err(train)=2.14 acc(train)=0.23 run_time=25.04s | err(valid)=1.99 acc(valid)=0.28
# RNN_MSD10  LR = 0.001 Done! Avg. Epoch Time: 25.04s, Best Val. Error: 1.99, Best Val. Accuracy: 0.28

# %%
MSD10_basic.save_data('MSD10_basic')

# %%
MSD25_basic=net.RNN_Model(num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic.run_session()
# Out:
#   File "<ipython-input-19-6419b430d387>", line 1
#     1e-(4/6)
#       ^
# SyntaxError: invalid token

# %%
MSD25_basic.save_data('MSD25_basic')
