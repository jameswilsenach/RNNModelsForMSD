# %%
import rnn_networks as net
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
MSD10_basic_lr4=net.RNN_Model(title='MSD10_basic_lr4',num_hidden=200,lam=1e-3,lr=1e-4,num_epochs=40)
MSD10_basic_lr4.run_session()
MSD10_basic_lr3=net.RNN_Model(title='MSD10_basic_lr3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_basic_lr3.run_session()

# %%
MSD25_basic_lr4=net.RNN_Model(title='MSD25_basic_lr4',num_hidden=200,lam=1e-3,lr=1e-4,num_epochs=40,provider=1)
MSD25_basic_lr4.run_session()
MSD25_basic_lr3=net.RNN_Model(title='MSD25_basic_lr3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic_lr3.run_session()
# Out:
# End of epoch 01: err(train)=3.38 acc(train)=0.15 run_time=252.97s | err(valid)=3.20 acc(valid)=0.19
# End of epoch 02: err(train)=3.12 acc(train)=0.20 run_time=283.34s | err(valid)=3.10 acc(valid)=0.21
# End of epoch 03: err(train)=3.03 acc(train)=0.22 run_time=278.35s | err(valid)=3.05 acc(valid)=0.21
# End of epoch 04: err(train)=2.96 acc(train)=0.23 run_time=252.56s | err(valid)=3.00 acc(valid)=0.22
# End of epoch 05: err(train)=2.91 acc(train)=0.24 run_time=283.05s | err(valid)=2.96 acc(valid)=0.23
# End of epoch 06: err(train)=2.86 acc(train)=0.25 run_time=283.37s | err(valid)=2.93 acc(valid)=0.23
# End of epoch 07: err(train)=2.83 acc(train)=0.26 run_time=252.94s | err(valid)=2.90 acc(valid)=0.23
# End of epoch 08: err(train)=2.79 acc(train)=0.27 run_time=283.61s | err(valid)=2.88 acc(valid)=0.24
# End of epoch 09: err(train)=2.76 acc(train)=0.27 run_time=366.97s | err(valid)=2.86 acc(valid)=0.23
# ...

# %%
MSD10_basic_lr4_h100=net.RNN_Model(title='MSD10_basic_lr4_h100',num_hidden=100,lam=1e-3,lr=1e-4,num_epochs=40)
MSD10_basic_lr4_h100.run_session()
MSD10_basic_lr3_h100=net.RNN_Model(title='MSD10_basic_lr3_h_100',num_hidden=100,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_basic_lr3_h100.run_session()
# Out:
# End of epoch 01: err(train)=2.19 acc(train)=0.31 run_time=150.18s | err(valid)=1.95 acc(valid)=0.41
# End of epoch 02: err(train)=1.86 acc(train)=0.43 run_time=160.28s | err(valid)=1.83 acc(valid)=0.45
# End of epoch 03: err(train)=1.77 acc(train)=0.46 run_time=143.70s | err(valid)=1.78 acc(valid)=0.46
# End of epoch 04: err(train)=1.72 acc(train)=0.48 run_time=157.58s | err(valid)=1.73 acc(valid)=0.48
# End of epoch 05: err(train)=1.68 acc(train)=0.49 run_time=163.00s | err(valid)=1.70 acc(valid)=0.48
# End of epoch 06: err(train)=1.64 acc(train)=0.50 run_time=227.81s | err(valid)=1.67 acc(valid)=0.49
# End of epoch 07: err(train)=1.60 acc(train)=0.51 run_time=201.66s | err(valid)=1.64 acc(valid)=0.50
# End of epoch 08: err(train)=1.58 acc(train)=0.52 run_time=160.00s | err(valid)=1.62 acc(valid)=0.51
# End of epoch 09: err(train)=1.55 acc(train)=0.53 run_time=152.50s | err(valid)=1.60 acc(valid)=0.52
# ...

# %%
MSD10_basic_lr3_h100=net.RNN_Model('test',num_hidden=100,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_basic_lr3_h100.run_session()
# Out:
# End of epoch 01: err(train)=1.72 acc(train)=0.42 run_time=92.09s | err(valid)=1.62 acc(valid)=0.45
# End of epoch 02: err(train)=1.54 acc(train)=0.48 run_time=92.33s | err(valid)=1.51 acc(valid)=0.50
# End of epoch 03: err(train)=1.43 acc(train)=0.52 run_time=91.46s | err(valid)=1.43 acc(valid)=0.52
# End of epoch 04: err(train)=1.33 acc(train)=0.55 run_time=91.75s | err(valid)=1.35 acc(valid)=0.55
# End of epoch 05: err(train)=1.27 acc(train)=0.58 run_time=91.22s | err(valid)=1.32 acc(valid)=0.56
# End of epoch 06: err(train)=1.21 acc(train)=0.59 run_time=91.03s | err(valid)=1.27 acc(valid)=0.57
# End of epoch 07: err(train)=1.17 acc(train)=0.61 run_time=90.40s | err(valid)=1.25 acc(valid)=0.58
# End of epoch 08: err(train)=1.13 acc(train)=0.62 run_time=90.14s | err(valid)=1.22 acc(valid)=0.59
# End of epoch 09: err(train)=1.09 acc(train)=0.64 run_time=90.44s | err(valid)=1.20 acc(valid)=0.60
# ...

# %%
MSD25_basic_lr4_h100=net.RNN_Model(title='MSD25_basic_lr4_h100',num_hidden=100,lam=1e-3,lr=1e-4,num_epochs=40,provider=1)
MSD25_basic_lr4_h100.run_session()

# %%
MSD25_basic_lr3_h100=net.RNN_Model(title='MSD25_basic_lr3_h100',num_hidden=100,lam=1e-3,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic_lr3_h100.run_session()
# Out:
# End of epoch 01: err(train)=3.00 acc(train)=0.17 run_time=95.52s | err(valid)=2.93 acc(valid)=0.17
# End of epoch 02: err(train)=2.81 acc(train)=0.20 run_time=95.01s | err(valid)=2.81 acc(valid)=0.20
# End of epoch 03: err(train)=2.74 acc(train)=0.22 run_time=98.70s | err(valid)=2.76 acc(valid)=0.21
# End of epoch 04: err(train)=2.69 acc(train)=0.23 run_time=97.17s | err(valid)=2.71 acc(valid)=0.22
# End of epoch 05: err(train)=2.64 acc(train)=0.24 run_time=95.82s | err(valid)=2.67 acc(valid)=0.23
# End of epoch 06: err(train)=2.61 acc(train)=0.25 run_time=98.50s | err(valid)=2.67 acc(valid)=0.23
# End of epoch 07: err(train)=2.60 acc(train)=0.26 run_time=99.10s | err(valid)=2.63 acc(valid)=0.24
# End of epoch 08: err(train)=2.56 acc(train)=0.26 run_time=96.54s | err(valid)=2.62 acc(valid)=0.24
# End of epoch 09: err(train)=2.53 acc(train)=0.27 run_time=96.17s | err(valid)=2.61 acc(valid)=0.25
# ...

# %%
from rnn_providers import GapMSD10DataProvider
import numpy as np

# %%
seed = 123
rng = np.random.RandomState(seed)
batch_size = 50
test = GapMSD10DataProvider('train', batch_size=batch_size, rng=rng)
# Out:
# (40000, 250)
# (40000, 1)

# %%
MSD10_aug_lr3=net.Aug_RNN_Model(title='MSD10_aug_lr3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_aug_lr3.run_session()
# Out:
# (40000, 3000)
# (50000, 3000)
# End of epoch 01: err(train)=1.96 acc(train)=0.43 run_time=322.10s | err(valid)=1.83 acc(valid)=0.45
# End of epoch 02: err(train)=1.69 acc(train)=0.48 run_time=310.19s | err(valid)=1.64 acc(valid)=0.50
# End of epoch 03: err(train)=1.58 acc(train)=0.52 run_time=313.62s | err(valid)=1.53 acc(valid)=0.53
# End of epoch 04: err(train)=1.50 acc(train)=0.54 run_time=314.45s | err(valid)=1.52 acc(valid)=0.54
# End of epoch 05: err(train)=1.45 acc(train)=0.56 run_time=315.58s | err(valid)=1.47 acc(valid)=0.55
# End of epoch 06: err(train)=1.39 acc(train)=0.58 run_time=316.77s | err(valid)=1.43 acc(valid)=0.57
# End of epoch 07: err(train)=1.36 acc(train)=0.59 run_time=301.08s | err(valid)=1.39 acc(valid)=0.59
# End of epoch 08: err(train)=1.32 acc(train)=0.61 run_time=303.07s | err(valid)=1.39 acc(valid)=0.59
# End of epoch 09: err(train)=1.29 acc(train)=0.62 run_time=300.16s | err(valid)=1.35 acc(valid)=0.60
# ...

# %%
MSD25_aug_lr3=net.Aug_RNN_Model(title='MSD25_aug_lr3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1)
MSD25_aug_lr3.run_session()
# Out:
# End of epoch 01: err(train)=3.07 acc(train)=0.18 run_time=299.78s | err(valid)=2.91 acc(valid)=0.19
# End of epoch 02: err(train)=2.81 acc(train)=0.21 run_time=287.47s | err(valid)=2.83 acc(valid)=0.20
# End of epoch 03: err(train)=2.77 acc(train)=0.22 run_time=282.78s | err(valid)=2.78 acc(valid)=0.21
# End of epoch 04: err(train)=2.70 acc(train)=0.24 run_time=281.14s | err(valid)=2.73 acc(valid)=0.22
# End of epoch 05: err(train)=2.65 acc(train)=0.24 run_time=306.00s | err(valid)=2.71 acc(valid)=0.23
# End of epoch 06: err(train)=2.61 acc(train)=0.26 run_time=283.23s | err(valid)=2.67 acc(valid)=0.24
# End of epoch 07: err(train)=2.58 acc(train)=0.27 run_time=291.66s | err(valid)=2.65 acc(valid)=0.25
# End of epoch 08: err(train)=2.56 acc(train)=0.27 run_time=284.79s | err(valid)=2.66 acc(valid)=0.24
# End of epoch 09: err(train)=2.55 acc(train)=0.28 run_time=381.07s | err(valid)=2.63 acc(valid)=0.25
# ...

# %%
MSD25_aug_p1=net.Aug_RNN_Model(title='MSD25_aug_p1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,pdrop=0.1,provider=1)
MSD25_aug_p1.run_session()
# Out:
# End of epoch 01: err(train)=3.11 acc(train)=0.17 run_time=231.16s | err(valid)=2.96 acc(valid)=0.18
# End of epoch 02: err(train)=2.86 acc(train)=0.21 run_time=230.92s | err(valid)=2.85 acc(valid)=0.21
# End of epoch 03: err(train)=2.78 acc(train)=0.22 run_time=229.73s | err(valid)=2.80 acc(valid)=0.21
# End of epoch 04: err(train)=2.76 acc(train)=0.22 run_time=229.73s | err(valid)=2.84 acc(valid)=0.21
# End of epoch 05: err(train)=2.70 acc(train)=0.24 run_time=229.83s | err(valid)=2.72 acc(valid)=0.23
# End of epoch 06: err(train)=2.63 acc(train)=0.26 run_time=230.92s | err(valid)=2.72 acc(valid)=0.23
# End of epoch 07: err(train)=2.59 acc(train)=0.27 run_time=230.88s | err(valid)=2.67 acc(valid)=0.24
# End of epoch 08: err(train)=2.56 acc(train)=0.27 run_time=231.32s | err(valid)=2.63 acc(valid)=0.25
# End of epoch 09: err(train)=2.54 acc(train)=0.28 run_time=230.63s | err(valid)=2.62 acc(valid)=0.25
# ...

# %%
MSD25_aug_s1=net.Aug_RNN_Model(title='MSD25_aug_s1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,std=0.1,provider=1)
MSD25_aug_s1.run_session()
# Out:
# End of epoch 01: err(train)=3.09 acc(train)=0.17 run_time=232.18s | err(valid)=2.95 acc(valid)=0.19
# End of epoch 02: err(train)=2.84 acc(train)=0.21 run_time=231.66s | err(valid)=2.84 acc(valid)=0.20

# %%
MSD10_aug_lr3_p1=net.Aug_RNN_Model(title='MSD10_aug_lr3_p1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,pdrop=0.1)
MSD10_aug_lr3_p1.run_session()
# Out:
# End of epoch 01: err(train)=1.98 acc(train)=0.43 run_time=352.87s | err(valid)=1.84 acc(valid)=0.45
# End of epoch 02: err(train)=1.69 acc(train)=0.48 run_time=343.44s | err(valid)=1.65 acc(valid)=0.50
# End of epoch 03: err(train)=1.59 acc(train)=0.52 run_time=351.08s | err(valid)=1.59 acc(valid)=0.52
# End of epoch 04: err(train)=1.52 acc(train)=0.54 run_time=398.73s | err(valid)=1.56 acc(valid)=0.54
# End of epoch 05: err(train)=1.45 acc(train)=0.57 run_time=422.15s | err(valid)=1.44 acc(valid)=0.57
# End of epoch 06: err(train)=1.38 acc(train)=0.59 run_time=416.39s | err(valid)=1.43 acc(valid)=0.57
# End of epoch 07: err(train)=1.33 acc(train)=0.60 run_time=399.63s | err(valid)=1.38 acc(valid)=0.59
# End of epoch 08: err(train)=1.29 acc(train)=0.62 run_time=417.78s | err(valid)=1.35 acc(valid)=0.60
# End of epoch 09: err(train)=1.26 acc(train)=0.63 run_time=412.84s | err(valid)=1.33 acc(valid)=0.60
# ...

# %%
MSD10_aug_lr3_s1=net.Aug_RNN_Model(title='MSD10_aug_lr3_s1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,std=0.1)
MSD10_aug_lr3_s1.run_session()
# Out:
# End of epoch 01: err(train)=1.95 acc(train)=0.43 run_time=232.65s | err(valid)=1.78 acc(valid)=0.46
# End of epoch 02: err(train)=1.69 acc(train)=0.48 run_time=232.88s | err(valid)=1.70 acc(valid)=0.47
# End of epoch 03: err(train)=1.64 acc(train)=0.51 run_time=232.03s | err(valid)=1.61 acc(valid)=0.52
# End of epoch 04: err(train)=1.54 acc(train)=0.54 run_time=230.02s | err(valid)=1.57 acc(valid)=0.53
# End of epoch 05: err(train)=1.48 acc(train)=0.56 run_time=230.96s | err(valid)=1.53 acc(valid)=0.54
# End of epoch 06: err(train)=1.45 acc(train)=0.57 run_time=230.34s | err(valid)=1.47 acc(valid)=0.56
# End of epoch 07: err(train)=1.41 acc(train)=0.58 run_time=229.81s | err(valid)=1.44 acc(valid)=0.58
# End of epoch 08: err(train)=1.38 acc(train)=0.60 run_time=230.61s | err(valid)=1.43 acc(valid)=0.58
# End of epoch 09: err(train)=1.34 acc(train)=0.61 run_time=230.27s | err(valid)=1.40 acc(valid)=0.59
# ...

# %%
MSD25_aug_lr3_p1=net.Aug_RNN_Model(title='MSD25_aug_lr3_p1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,pdrop=0.1,provider=1)
MSD25_aug_lr3_p1.run_session()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-cf10616e2d34> in <module>()
# ----> 1 MSD25_aug_lr3_p1=net.Aug_RNN_Model(title='MSD25_aug_lr3_p1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,pdrop=0.1,provider=1)
#       2 MSD25_aug_lr3_p1.run_session()
#
# /afs/inf.ed.ac.uk/user/s16/s1666320/my_mlp/4/rnn_networks.pyc in __init__(self, title, num_hidden, lr, num_epochs, provider, out, lam, fraction, std, pdrop)
#     180     def __init__(self,title='',num_hidden=200,lr=1e-3,num_epochs=10,provider=0,out=1,lam=1e-3,
#     181                  fraction=0.25,std=0.05,pdrop=0.2):
# --> 182         super(Aug_RNN_Model,self).__init__(title,num_hidden,lr,num_epochs,provider,out,lam)
#     183         self.fraction=fraction
#     184         self.std=std
#
# ...

# %%
MSD10_aug_p1_s1=net.Aug_RNN_Model(title='MSD10_aug_p1_s1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,pdrop=0.1,std=0.1)
MSD10_aug_p1_s1.run_session()
# Out:
# End of epoch 01: err(train)=1.98 acc(train)=0.42 run_time=191.58s | err(valid)=1.79 acc(valid)=0.47
# End of epoch 02: err(train)=1.69 acc(train)=0.49 run_time=189.14s | err(valid)=1.64 acc(valid)=0.51
# End of epoch 03: err(train)=1.57 acc(train)=0.52 run_time=188.60s | err(valid)=1.56 acc(valid)=0.52
# End of epoch 04: err(train)=1.49 acc(train)=0.54 run_time=183.37s | err(valid)=1.50 acc(valid)=0.55
# End of epoch 05: err(train)=1.42 acc(train)=0.57 run_time=185.74s | err(valid)=1.44 acc(valid)=0.57
# End of epoch 06: err(train)=1.37 acc(train)=0.59 run_time=185.09s | err(valid)=1.39 acc(valid)=0.59
# End of epoch 07: err(train)=1.33 acc(train)=0.61 run_time=184.15s | err(valid)=1.38 acc(valid)=0.58
# End of epoch 08: err(train)=1.28 acc(train)=0.62 run_time=185.01s | err(valid)=1.40 acc(valid)=0.58
# End of epoch 09: err(train)=1.25 acc(train)=0.63 run_time=186.71s | err(valid)=1.34 acc(valid)=0.60
# ...

# %%
MSD25_aug_p1_s1=net.Aug_RNN_Model(title='MSD25_aug_p1_s1',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,pdrop=0.1,provider=1,std=0.1)
MSD25_aug_p1_s1.run_session()
# Out:
# End of epoch 01: err(train)=3.11 acc(train)=0.18 run_time=190.63s | err(valid)=3.06 acc(valid)=0.17
# End of epoch 02: err(train)=2.90 acc(train)=0.20 run_time=189.73s | err(valid)=2.89 acc(valid)=0.19
# End of epoch 03: err(train)=2.83 acc(train)=0.21 run_time=191.13s | err(valid)=2.86 acc(valid)=0.20
# End of epoch 04: err(train)=2.78 acc(train)=0.22 run_time=190.81s | err(valid)=2.79 acc(valid)=0.22
# End of epoch 05: err(train)=2.72 acc(train)=0.24 run_time=186.66s | err(valid)=2.74 acc(valid)=0.22
# End of epoch 06: err(train)=2.67 acc(train)=0.25 run_time=189.76s | err(valid)=2.71 acc(valid)=0.23
# End of epoch 07: err(train)=2.65 acc(train)=0.25 run_time=186.63s | err(valid)=2.70 acc(valid)=0.23
# End of epoch 08: err(train)=2.61 acc(train)=0.26 run_time=187.60s | err(valid)=2.67 acc(valid)=0.24
# End of epoch 09: err(train)=2.57 acc(train)=0.27 run_time=189.54s | err(valid)=2.64 acc(valid)=0.25
# ...

# %%
MSD25_multi_a30 = net.Multi_RNN_Model(title='MSD25_multi_a30',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1,alpha=3,outputs=10)

# %%
MSD25_multi_a30.run_session()
# Out:
# End of epoch 01: err(tr)=3.22 acc(train)=0.17 err2=0.87 run_time=168.70s | err(v)=3.04 acc(valid)=0.20
# End of epoch 02: err(tr)=2.98 acc(train)=0.21 err2=0.84 run_time=168.93s | err(v)=2.96 acc(valid)=0.20
# End of epoch 03: err(tr)=2.91 acc(train)=0.22 err2=0.83 run_time=169.12s | err(v)=2.95 acc(valid)=0.21
# End of epoch 04: err(tr)=2.86 acc(train)=0.23 err2=0.82 run_time=168.78s | err(v)=2.89 acc(valid)=0.22
# End of epoch 05: err(tr)=2.81 acc(train)=0.24 err2=0.82 run_time=168.08s | err(v)=2.86 acc(valid)=0.23
# End of epoch 06: err(tr)=2.78 acc(train)=0.25 err2=0.81 run_time=170.46s | err(v)=2.82 acc(valid)=0.24
# End of epoch 07: err(tr)=2.75 acc(train)=0.26 err2=0.80 run_time=167.81s | err(v)=2.81 acc(valid)=0.25
# End of epoch 08: err(tr)=2.71 acc(train)=0.27 err2=0.79 run_time=167.26s | err(v)=2.80 acc(valid)=0.24
# End of epoch 09: err(tr)=2.69 acc(train)=0.28 err2=0.79 run_time=167.23s | err(v)=2.76 acc(valid)=0.25
# ...

# %%
MSD25_multi_a20 = net.Multi_RNN_Model(title='MSD25_multi_a20',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1,alpha=2,outputs=10)

# %%
MSD25_multi_a20.run_session()
# Out:
# End of epoch 01: err(tr)=3.18 acc(train)=0.18 err2=0.88 run_time=170.01s | err(v)=3.03 acc(valid)=0.19
# End of epoch 02: err(tr)=2.95 acc(train)=0.20 err2=0.86 run_time=167.31s | err(v)=2.98 acc(valid)=0.19
# End of epoch 03: err(tr)=2.88 acc(train)=0.21 err2=0.85 run_time=166.88s | err(v)=2.90 acc(valid)=0.20
# End of epoch 04: err(tr)=2.83 acc(train)=0.23 err2=0.85 run_time=167.53s | err(v)=2.88 acc(valid)=0.22
# End of epoch 05: err(tr)=2.79 acc(train)=0.24 err2=0.84 run_time=169.32s | err(v)=2.82 acc(valid)=0.22
# End of epoch 06: err(tr)=2.76 acc(train)=0.24 err2=0.84 run_time=168.36s | err(v)=2.79 acc(valid)=0.23
# End of epoch 07: err(tr)=2.73 acc(train)=0.25 err2=0.83 run_time=170.26s | err(v)=2.77 acc(valid)=0.24
# End of epoch 08: err(tr)=2.71 acc(train)=0.26 err2=0.82 run_time=167.67s | err(v)=2.80 acc(valid)=0.23
# End of epoch 09: err(tr)=2.68 acc(train)=0.27 err2=0.82 run_time=169.83s | err(v)=2.76 acc(valid)=0.24
# ...

# %%
MSD25_multi_a10 = net.Multi_RNN_Model(title='MSD25_multi_a10',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1,alpha=1,outputs=10)

# %%
MSD25_multi_a10.run_session()
# Out:
# End of epoch 01: err(tr)=3.16 acc(train)=0.17 err2=0.90 run_time=167.06s | err(v)=2.97 acc(valid)=0.19
# End of epoch 02: err(tr)=2.90 acc(train)=0.20 err2=0.89 run_time=166.42s | err(v)=2.89 acc(valid)=0.20
# End of epoch 03: err(tr)=2.83 acc(train)=0.21 err2=0.89 run_time=166.85s | err(v)=2.87 acc(valid)=0.20
# End of epoch 04: err(tr)=2.80 acc(train)=0.22 err2=0.88 run_time=166.49s | err(v)=2.81 acc(valid)=0.21
# End of epoch 05: err(tr)=2.77 acc(train)=0.23 err2=0.88 run_time=166.98s | err(v)=2.81 acc(valid)=0.21
# End of epoch 06: err(tr)=2.73 acc(train)=0.24 err2=0.88 run_time=167.18s | err(v)=2.83 acc(valid)=0.21
# End of epoch 07: err(tr)=2.73 acc(train)=0.24 err2=0.88 run_time=166.99s | err(v)=2.76 acc(valid)=0.23
# End of epoch 08: err(tr)=2.68 acc(train)=0.25 err2=0.87 run_time=166.83s | err(v)=2.73 acc(valid)=0.23
# End of epoch 09: err(tr)=2.69 acc(train)=0.25 err2=0.87 run_time=166.93s | err(v)=2.72 acc(valid)=0.24
# ...

# %%
MSD10_multi_a10 = net.Multi_RNN_Model(title='MSD10_multi_a10',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=1,outputs=10)

# %%
MSD10_multi_a10.run_session()
# Out:
# End of epoch 01: err(tr)=2.05 acc(train)=0.42 err2=0.91 run_time=175.44s | err(v)=1.87 acc(valid)=0.46
# End of epoch 02: err(tr)=1.77 acc(train)=0.47 err2=0.90 run_time=172.49s | err(v)=1.76 acc(valid)=0.47
# End of epoch 03: err(tr)=1.72 acc(train)=0.49 err2=0.90 run_time=171.25s | err(v)=1.68 acc(valid)=0.51
# End of epoch 04: err(tr)=1.59 acc(train)=0.53 err2=0.89 run_time=171.12s | err(v)=1.60 acc(valid)=0.52
# End of epoch 05: err(tr)=1.51 acc(train)=0.56 err2=0.89 run_time=171.38s | err(v)=1.51 acc(valid)=0.56
# End of epoch 06: err(tr)=1.45 acc(train)=0.57 err2=0.88 run_time=170.93s | err(v)=1.49 acc(valid)=0.56
# End of epoch 07: err(tr)=1.41 acc(train)=0.59 err2=0.88 run_time=170.95s | err(v)=1.45 acc(valid)=0.58
# End of epoch 08: err(tr)=1.37 acc(train)=0.60 err2=0.88 run_time=170.73s | err(v)=1.45 acc(valid)=0.57
# End of epoch 09: err(tr)=1.34 acc(train)=0.61 err2=0.87 run_time=173.13s | err(v)=1.43 acc(valid)=0.58
# ...

# %%
MSD10_multi_a30 = net.Multi_RNN_Model(title='MSD10_multi_a30',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=3,outputs=10)

# %%
MSD10_multi_a30.run_session()
# Out:
# End of epoch 01: err(tr)=2.09 acc(train)=0.42 err2=0.87 run_time=170.15s | err(v)=1.90 acc(valid)=0.46
# End of epoch 02: err(tr)=1.83 acc(train)=0.48 err2=0.85 run_time=169.01s | err(v)=1.82 acc(valid)=0.48
# End of epoch 03: err(tr)=1.74 acc(train)=0.50 err2=0.84 run_time=168.84s | err(v)=1.73 acc(valid)=0.51
# End of epoch 04: err(tr)=1.66 acc(train)=0.53 err2=0.83 run_time=169.34s | err(v)=1.67 acc(valid)=0.53
# End of epoch 05: err(tr)=1.61 acc(train)=0.55 err2=0.82 run_time=169.51s | err(v)=1.60 acc(valid)=0.55
# End of epoch 06: err(tr)=1.55 acc(train)=0.57 err2=0.81 run_time=171.32s | err(v)=1.57 acc(valid)=0.57
# End of epoch 07: err(tr)=1.49 acc(train)=0.59 err2=0.80 run_time=169.76s | err(v)=1.56 acc(valid)=0.57
# End of epoch 08: err(tr)=1.45 acc(train)=0.61 err2=0.79 run_time=169.94s | err(v)=1.51 acc(valid)=0.59
# End of epoch 09: err(tr)=1.42 acc(train)=0.62 err2=0.79 run_time=169.60s | err(v)=1.54 acc(valid)=0.59
# ...

# %%
MSD10_multi_a50 = net.Multi_RNN_Model(title='MSD10_multi_a50',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=5,outputs=10)

# %%
MSD10_multi_a50.run_session()
# Out:
# End of epoch 01: err(tr)=2.13 acc(train)=0.43 err2=0.85 run_time=169.04s | err(v)=1.96 acc(valid)=0.45
# End of epoch 02: err(tr)=1.86 acc(train)=0.49 err2=0.82 run_time=168.62s | err(v)=1.84 acc(valid)=0.50
# End of epoch 03: err(tr)=1.74 acc(train)=0.52 err2=0.80 run_time=168.40s | err(v)=1.76 acc(valid)=0.53
# End of epoch 04: err(tr)=1.65 acc(train)=0.56 err2=0.78 run_time=171.45s | err(v)=1.65 acc(valid)=0.56
# End of epoch 05: err(tr)=1.57 acc(train)=0.58 err2=0.77 run_time=167.71s | err(v)=1.61 acc(valid)=0.57
# End of epoch 06: err(tr)=1.52 acc(train)=0.60 err2=0.77 run_time=169.51s | err(v)=1.59 acc(valid)=0.57
# End of epoch 07: err(tr)=1.49 acc(train)=0.61 err2=0.77 run_time=166.22s | err(v)=1.54 acc(valid)=0.61
# End of epoch 08: err(tr)=1.45 acc(train)=0.63 err2=0.77 run_time=166.82s | err(v)=1.57 acc(valid)=0.59
# End of epoch 09: err(tr)=1.43 acc(train)=0.63 err2=0.76 run_time=167.42s | err(v)=1.56 acc(valid)=0.59
# ...

# %%
MSD10_multi_a20 = net.Multi_RNN_Model(title='MSD10_multi_a20',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=2,outputs=10)

# %%
MSD10_multi_a20.run_session()
# Out:
# End of epoch 01: err(tr)=2.07 acc(train)=0.43 err2=0.89 run_time=173.04s | err(v)=1.89 acc(valid)=0.46
# End of epoch 02: err(tr)=1.81 acc(train)=0.47 err2=0.87 run_time=171.54s | err(v)=1.82 acc(valid)=0.46
# End of epoch 03: err(tr)=1.73 acc(train)=0.49 err2=0.86 run_time=171.96s | err(v)=1.71 acc(valid)=0.51
# End of epoch 04: err(tr)=1.64 acc(train)=0.53 err2=0.85 run_time=171.42s | err(v)=1.68 acc(valid)=0.51
# End of epoch 05: err(tr)=1.57 acc(train)=0.55 err2=0.84 run_time=170.48s | err(v)=1.61 acc(valid)=0.55
# End of epoch 06: err(tr)=1.52 acc(train)=0.57 err2=0.84 run_time=170.83s | err(v)=1.57 acc(valid)=0.55
# End of epoch 07: err(tr)=1.48 acc(train)=0.59 err2=0.83 run_time=172.39s | err(v)=1.53 acc(valid)=0.58
# End of epoch 08: err(tr)=1.45 acc(train)=0.60 err2=0.82 run_time=172.07s | err(v)=1.50 acc(valid)=0.58
# End of epoch 09: err(tr)=1.41 acc(train)=0.61 err2=0.82 run_time=171.30s | err(v)=1.51 acc(valid)=0.58
# ...

# %%
MSD10_multi_a30_nr = net.Multi_RNN_Model(title='MSD10_multi_a30_nr',num_hidden=200,lam=0,lr=1e-3,num_epochs=40,alpha=3,outputs=10)

# %%
MSD10_multi_a30_nr.run_session()
# Out:
# End of epoch 01: err(tr)=1.59 acc(train)=0.43 err2=0.85 run_time=171.29s | err(v)=1.48 acc(valid)=0.47
# End of epoch 02: err(tr)=1.39 acc(train)=0.51 err2=0.81 run_time=170.18s | err(v)=1.33 acc(valid)=0.54
# End of epoch 03: err(tr)=1.24 acc(train)=0.56 err2=0.79 run_time=168.93s | err(v)=1.24 acc(valid)=0.57
# End of epoch 04: err(tr)=1.13 acc(train)=0.60 err2=0.77 run_time=169.04s | err(v)=1.18 acc(valid)=0.59
# End of epoch 05: err(tr)=1.05 acc(train)=0.63 err2=0.76 run_time=168.60s | err(v)=1.14 acc(valid)=0.60
# End of epoch 06: err(tr)=0.98 acc(train)=0.66 err2=0.76 run_time=168.81s | err(v)=1.11 acc(valid)=0.61
# End of epoch 07: err(tr)=0.92 acc(train)=0.68 err2=0.76 run_time=168.82s | err(v)=1.11 acc(valid)=0.62
# End of epoch 08: err(tr)=0.85 acc(train)=0.70 err2=0.76 run_time=167.55s | err(v)=1.13 acc(valid)=0.62
# End of epoch 09: err(tr)=0.79 acc(train)=0.72 err2=0.75 run_time=167.46s | err(v)=1.11 acc(valid)=0.63
# ...

# %%
MSD10_auto_a30_r4 = net.MultiAuto_RNN_Model(title='MSD10_multi_a30_r4',num_hidden=200,lam=1e-4,lr=1e-3,num_epochs=40,alpha=3,outputs=10)

# %%
MSD10_auto_a30_r4.run_session()
# Out:
# End of epoch 01: err(tr)=1.65 acc(train)=0.43 err2=0.85 run_time=192.17s | err(v)=1.58 acc(valid)=0.46
# End of epoch 02: err(tr)=1.46 acc(train)=0.50 err2=0.82 run_time=191.66s | err(v)=1.41 acc(valid)=0.52
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-91899612668e> in <module>()
# ----> 1 MSD10_auto_a30_r4.run_session()
#
# /afs/inf.ed.ac.uk/user/s16/s1666320/my_mlp/4/rnn_networks.py in run_session(self)
#     281                 _, batch_error1, _, batch_acc, batch_error2 = sess.run(
#     282                     [self.train_step,self.error1, self.error, self.accuracy, self.error2],
# --> 283                     feed_dict={self.inputs: input_batch, self.targets_1: target_batch1, self.targets_2: target_batch2})
#     284                 running_error += batch_error1
#     285                 running_error2 += batch_error2
#
# ...

# %%
MSD10_multi = net.MultiClass_RNN_Model(title='MSD10_multi',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=0.5,outputs=10)

# %%
MSD10_multi.run_session()
# Out:
# End of epoch 01: err(tr)=2.13 acc(train)=0.41 err2=2.56 run_time=189.96s | err(v)=1.94 acc(valid)=0.45
# End of epoch 02: err(tr)=1.84 acc(train)=0.47 err2=2.28 run_time=189.39s | err(v)=1.75 acc(valid)=0.50
# End of epoch 03: err(tr)=1.68 acc(train)=0.52 err2=2.14 run_time=188.78s | err(v)=1.65 acc(valid)=0.52
# End of epoch 04: err(tr)=1.58 acc(train)=0.55 err2=2.02 run_time=188.82s | err(v)=1.59 acc(valid)=0.54
# End of epoch 05: err(tr)=1.50 acc(train)=0.57 err2=1.93 run_time=188.66s | err(v)=1.54 acc(valid)=0.56
# End of epoch 06: err(tr)=1.44 acc(train)=0.60 err2=1.84 run_time=188.27s | err(v)=1.47 acc(valid)=0.59
# End of epoch 07: err(tr)=1.40 acc(train)=0.61 err2=1.78 run_time=189.37s | err(v)=1.44 acc(valid)=0.60
# End of epoch 08: err(tr)=1.36 acc(train)=0.63 err2=1.72 run_time=188.82s | err(v)=1.43 acc(valid)=0.61
# End of epoch 09: err(tr)=1.33 acc(train)=0.64 err2=1.67 run_time=188.98s | err(v)=1.43 acc(valid)=0.61
# ...

# %%
MSD25_multi = net.MultiClass_RNN_Model(title='MSD10_multi',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=1.5,outputs=10,provider=1)

# %%
MSD25_multi.run_session()
# Out:
# End of epoch 01: err(tr)=3.41 acc(train)=0.15 err2=3.87 run_time=186.94s | err(v)=3.22 acc(valid)=0.18
# End of epoch 02: err(tr)=3.12 acc(train)=0.20 err2=3.59 run_time=185.78s | err(v)=3.05 acc(valid)=0.21
# End of epoch 03: err(tr)=2.97 acc(train)=0.22 err2=3.49 run_time=186.20s | err(v)=2.93 acc(valid)=0.23
# End of epoch 04: err(tr)=2.85 acc(train)=0.25 err2=3.39 run_time=185.39s | err(v)=2.86 acc(valid)=0.24
# End of epoch 05: err(tr)=2.78 acc(train)=0.27 err2=3.32 run_time=185.34s | err(v)=2.81 acc(valid)=0.25
# End of epoch 06: err(tr)=2.72 acc(train)=0.28 err2=3.26 run_time=184.22s | err(v)=2.80 acc(valid)=0.25
# End of epoch 07: err(tr)=2.69 acc(train)=0.29 err2=3.22 run_time=184.55s | err(v)=2.80 acc(valid)=0.26
# End of epoch 08: err(tr)=2.66 acc(train)=0.30 err2=3.17 run_time=184.84s | err(v)=2.78 acc(valid)=0.27
# End of epoch 09: err(tr)=2.64 acc(train)=0.31 err2=3.13 run_time=185.89s | err(v)=2.79 acc(valid)=0.27
# ...

# %%
MSD25_multi = net.MultiClass_RNN_Model(title='MSD10_multi',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,alpha=1.5,outputs=10,provider=1)

# %%
MSD25_multi.run_session()
# Out:
# End of epoch 01: err(tr)=3.04 acc(train)=0.16 err2=3.85 run_time=188.31s | err(v)=2.93 acc(valid)=0.18
# End of epoch 02: err(tr)=2.83 acc(train)=0.21 err2=3.57 run_time=188.72s | err(v)=2.77 acc(valid)=0.22
# End of epoch 03: err(tr)=2.69 acc(train)=0.24 err2=3.46 run_time=188.79s | err(v)=2.67 acc(valid)=0.23
# End of epoch 04: err(tr)=2.59 acc(train)=0.26 err2=3.36 run_time=188.32s | err(v)=2.62 acc(valid)=0.24
# End of epoch 05: err(tr)=2.51 acc(train)=0.27 err2=3.28 run_time=187.46s | err(v)=2.59 acc(valid)=0.25
# End of epoch 06: err(tr)=2.44 acc(train)=0.29 err2=3.21 run_time=188.21s | err(v)=2.56 acc(valid)=0.26
# End of epoch 07: err(tr)=2.39 acc(train)=0.31 err2=3.15 run_time=187.16s | err(v)=2.53 acc(valid)=0.27
# End of epoch 08: err(tr)=2.34 acc(train)=0.32 err2=3.08 run_time=187.86s | err(v)=2.53 acc(valid)=0.27
# End of epoch 09: err(tr)=2.29 acc(train)=0.34 err2=3.02 run_time=188.04s | err(v)=2.54 acc(valid)=0.27
# ...

# %%
MSD10_ens = net.Ens_RNN_Model(title='MSD10_ens',num_hidden=400,lam=1e-3,lr=1e-3,num_epochs=40,div=4,method=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e5fafe2eee07> in <module>()
# ----> 1 MSD10_ens = net.Ens_RNN_Model(title='MSD10_ens',num_hidden=400,lam=1e-3,lr=1e-3,num_epochs=40,div=4,method=1)
#
# NameError: name 'net' is not defined

# %%
MSD10_ens.run_session()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2c16ac8128bf> in <module>()
# ----> 1 MSD10_ens.run_session()
#
# NameError: name 'MSD10_ens' is not defined

# %%
MSD10_ens = net.Ens_RNN_Model(title='MSD10_ens',num_hidden=400,lam=1e-3,lr=1e-3,num_epochs=40,div=2,outputs=10,method=1)

# %%
MSD10_ens.run_session()
# Out:
# End of epoch 01: err(train)=2.15 acc(train)=0.46 run_time=121.89s | err(valid)=1.87 acc(valid)=0.48
# End of epoch 02: err(train)=1.74 acc(train)=0.51 run_time=121.30s | err(valid)=1.67 acc(valid)=0.52
# End of epoch 03: err(train)=1.63 acc(train)=0.53 run_time=122.34s | err(valid)=1.60 acc(valid)=0.54
# End of epoch 04: err(train)=1.57 acc(train)=0.55 run_time=122.13s | err(valid)=1.59 acc(valid)=0.54
# End of epoch 05: err(train)=1.53 acc(train)=0.56 run_time=122.30s | err(valid)=1.55 acc(valid)=0.56
# End of epoch 06: err(train)=1.50 acc(train)=0.58 run_time=122.60s | err(valid)=1.53 acc(valid)=0.57
# End of epoch 07: err(train)=1.47 acc(train)=0.59 run_time=122.65s | err(valid)=1.51 acc(valid)=0.58
# End of epoch 08: err(train)=1.45 acc(train)=0.60 run_time=122.78s | err(valid)=1.49 acc(valid)=0.59
# End of epoch 09: err(train)=1.43 acc(train)=0.61 run_time=123.31s | err(valid)=1.49 acc(valid)=0.59
# ...

# %%
MSD10_ens = net.Ens_RNN_Model(title='MSD10_ens',num_hidden=400,lam=1e-2,lr=1e-3,num_epochs=40,div=4,outputs=10)

# %%
MSD10_ens.run_session()
# Out:
# End of epoch 01: err(train)=3.07 acc(train)=0.38 run_time=40.77s | err(valid)=2.13 acc(valid)=0.38
# End of epoch 02: err(train)=2.12 acc(train)=0.38 run_time=40.56s | err(valid)=2.12 acc(valid)=0.38
# End of epoch 03: err(train)=2.11 acc(train)=0.38 run_time=40.94s | err(valid)=2.11 acc(valid)=0.39
# End of epoch 04: err(train)=2.11 acc(train)=0.38 run_time=41.13s | err(valid)=2.12 acc(valid)=0.37
# End of epoch 05: err(train)=2.11 acc(train)=0.38 run_time=40.88s | err(valid)=2.13 acc(valid)=0.38
# End of epoch 06: err(train)=2.11 acc(train)=0.38 run_time=41.52s | err(valid)=2.11 acc(valid)=0.39
# End of epoch 07: err(train)=2.11 acc(train)=0.38 run_time=41.17s | err(valid)=2.11 acc(valid)=0.39
# End of epoch 08: err(train)=2.11 acc(train)=0.38 run_time=42.46s | err(valid)=2.11 acc(valid)=0.37
# End of epoch 09: err(train)=2.11 acc(train)=0.38 run_time=42.29s | err(valid)=2.11 acc(valid)=0.38
# ...

# %%
MSD25_ens = net.Ens_RNN_Model(title='MSD25_ens',num_hidden=800,lam=1e-3,lr=1e-3,num_epochs=40,div=4,outputs=10,provider=1)

# %%
MSD25_ens.run_session()
# Out:
# End of epoch 01: err(train)=3.43 acc(train)=0.19 run_time=101.93s | err(valid)=2.98 acc(valid)=0.19
# End of epoch 02: err(train)=2.88 acc(train)=0.22 run_time=101.77s | err(valid)=2.84 acc(valid)=0.22
# End of epoch 03: err(train)=2.81 acc(train)=0.22 run_time=101.78s | err(valid)=2.82 acc(valid)=0.21
# End of epoch 04: err(train)=2.78 acc(train)=0.23 run_time=101.69s | err(valid)=2.80 acc(valid)=0.22
# End of epoch 05: err(train)=2.77 acc(train)=0.23 run_time=101.54s | err(valid)=2.79 acc(valid)=0.22
# End of epoch 06: err(train)=2.76 acc(train)=0.24 run_time=101.47s | err(valid)=2.78 acc(valid)=0.23
# End of epoch 07: err(train)=2.75 acc(train)=0.24 run_time=105.56s | err(valid)=2.77 acc(valid)=0.23
# End of epoch 08: err(train)=2.74 acc(train)=0.24 run_time=102.25s | err(valid)=2.77 acc(valid)=0.23
# End of epoch 09: err(train)=2.73 acc(train)=0.25 run_time=103.78s | err(valid)=2.76 acc(valid)=0.24
# ...

# %%
MSD25_ens = net.Ens_RNN_Model(title='MSD25_ens',num_hidden=400,lam=1e-4,lr=1e-3,num_epochs=40,div=4,provider=1)

# %%
MSD25_ens.run_session()
# Out:
# End of epoch 01: err(train)=45.48 acc(train)=0.07 run_time=38.90s | err(valid)=3.22 acc(valid)=0.04
# End of epoch 02: err(train)=3.22 acc(train)=0.04 run_time=39.44s | err(valid)=3.22 acc(valid)=0.04
# End of epoch 03: err(train)=3.22 acc(train)=0.04 run_time=46.74s | err(valid)=3.22 acc(valid)=0.04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-de8989a16bcb> in <module>()
# ----> 1 MSD25_ens.run_session()
#
# /afs/inf.ed.ac.uk/user/s16/s1666320/my_mlp/4/rnn_networks.py in run_session(self)
#     604                 for i in range(self.div):
#     605                     system_dict[self.inputs[i]] = input_batch[:,i,:,:]
# --> 606                 _, batch_error, batch_acc = sess.run([self.train_step,self.error, self.accuracy],feed_dict=system_dict)
#     607                 running_error += batch_error
# ...
