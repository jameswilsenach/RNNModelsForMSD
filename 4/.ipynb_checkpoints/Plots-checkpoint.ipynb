# %%
import rnn_networks as net
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
t11=np.load("MSD25_basic_lam4_h100.npy")

# %%
t12=np.load("MSD25_basic_lam4.npy")

# %%
t21=np.load("MSD25_basic_lam3_h100.npy")

# %%
t22=np.load("MSD25_basic_lam3.npy")

# %%
sims = [[t11,t12],[t21,t22]]

# %%
test = net.MultiPlot(sims,labels=['HU',r'$\lambda$'])

# %%
test.acc_curves([["lam4_h100","lam4_h200"],["lam3_h100","lam3_h200"]])

# %%
test.acc_heat(['1e-4','1e-3'],[100,200])

# %%
test.time_heat(['1e-4','1e-3'],[100,200])

# %%
t11=np.load("MSD25_basic_b50_h100.npy")

# %%
t12=np.load("MSD25_basic_b50_h200.npy")

# %%
t21=np.load("MSD25_basic_b100_h100.npy")

# %%
t22=np.load("MSD25_basic_b100_h200.npy")

# %%
sims = [[t11,t12],[t21,t22]]

# %%
test = net.MultiPlot(sims,labels=['HU',r'$\beta$'])

# %%
test.acc_curves([["b50_h100","b50_h200"],["b100_h100","b100_h200"]])

# %%
test.acc_heat(['50','100'],[100,200])

# %%
t11=np.load("MSD25_basic_lam3_h100.npy")

# %%
t22=np.load("MSD25_basic_b100_h100.npy")

# %%
sims = [[t11],[t22]]

# %%
test = net.MultiPlot(sims,labels=['lam','bet'])

# %%
test.acc_curves([["lam3_h100"],["b100_h100"]])
# Out:
# 0
# 0
# 1
# 0

# %%
test.d1
# Out:
# 1

# %%
test.d2
# Out:
# 1

# %%
len(sims)
# Out:
# 2
