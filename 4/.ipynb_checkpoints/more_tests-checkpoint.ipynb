# %%
import rnn_networks as net
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
MSD10_basic_lam4=net.RNN_Model(title='MSD10_basic_lam4',num_hidden=200,lam=1e-4,lr=1e-3,num_epochs=40)
MSD10_basic_lam4.run_session()
MSD10_basic_lam3=net.RNN_Model(title='MSD10_basic_lam3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_basic_lam3.run_session()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aac57aff4919> in <module>()
# ----> 1 MSD10_basic_lam4=net.RNN_Model(title='MSD10_basic_lam4',num_hidden=200,lam=1e-4,lr=1e-3,num_epochs=40)
#       2 MSD10_basic_lam4.run_session()
#       3 MSD10_basic_lam3=net.RNN_Model(title='MSD10_basic_lam3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40)
#       4 MSD10_basic_lam3.run_session()
#
# NameError: name 'net' is not defined

# %%
MSD10_stab_b100_h100=net.Norm_RNN_Model(title='MSD10_basic_b100_h100',num_hidden=100,beta=100,lr=1e-3,num_epochs=40)
MSD10_stab_b100_h100.run_session()
# Out:
# End of epoch 01: err(train)=1.96 acc(train)=0.41 run_time=104.98s | err(valid)=1.67 acc(valid)=0.46
# End of epoch 02: err(train)=1.55 acc(train)=0.49 run_time=103.08s | err(valid)=1.48 acc(valid)=0.50
# End of epoch 03: err(train)=1.41 acc(train)=0.53 run_time=102.87s | err(valid)=1.36 acc(valid)=0.54
# End of epoch 04: err(train)=1.31 acc(train)=0.56 run_time=103.10s | err(valid)=1.28 acc(valid)=0.57
# End of epoch 05: err(train)=1.24 acc(train)=0.58 run_time=102.60s | err(valid)=1.29 acc(valid)=0.55
# End of epoch 06: err(train)=1.19 acc(train)=0.59 run_time=102.71s | err(valid)=1.23 acc(valid)=0.58
# End of epoch 07: err(train)=1.15 acc(train)=0.61 run_time=103.00s | err(valid)=1.18 acc(valid)=0.60
# End of epoch 08: err(train)=1.11 acc(train)=0.62 run_time=103.18s | err(valid)=1.14 acc(valid)=0.61
# End of epoch 09: err(train)=1.08 acc(train)=0.63 run_time=102.74s | err(valid)=1.13 acc(valid)=0.61
# ...

# %%
MSD10_stab_b50_h100=net.Norm_RNN_Model(title='MSD10_basic_b50_h100',num_hidden=100,beta=50,lr=1e-3,num_epochs=40)
MSD10_stab_b50_h100.run_session()
# Out:
# End of epoch 01: err(train)=1.83 acc(train)=0.41 run_time=108.18s | err(valid)=1.60 acc(valid)=0.47
# End of epoch 02: err(train)=1.51 acc(train)=0.50 run_time=107.31s | err(valid)=1.43 acc(valid)=0.52
# End of epoch 03: err(train)=1.37 acc(train)=0.54 run_time=106.92s | err(valid)=1.44 acc(valid)=0.52
# End of epoch 04: err(train)=1.29 acc(train)=0.57 run_time=106.85s | err(valid)=1.29 acc(valid)=0.56
# End of epoch 05: err(train)=1.22 acc(train)=0.59 run_time=106.67s | err(valid)=1.21 acc(valid)=0.59
# End of epoch 06: err(train)=1.15 acc(train)=0.61 run_time=106.56s | err(valid)=1.18 acc(valid)=0.60
# End of epoch 07: err(train)=1.11 acc(train)=0.62 run_time=106.48s | err(valid)=1.18 acc(valid)=0.60
# End of epoch 08: err(train)=1.07 acc(train)=0.63 run_time=106.37s | err(valid)=1.13 acc(valid)=0.62
# End of epoch 09: err(train)=1.04 acc(train)=0.65 run_time=106.39s | err(valid)=1.12 acc(valid)=0.62
# ...

# %%
MSD10_stab_b50_h200=net.Norm_RNN_Model(title='MSD10_basic_b50_h200',num_hidden=200,beta=50,lr=1e-3,num_epochs=40)
MSD10_stab_b50_h200.run_session()
# Out:
# End of epoch 01: err(train)=1.80 acc(train)=0.42 run_time=212.16s | err(valid)=1.62 acc(valid)=0.46
# End of epoch 02: err(train)=1.49 acc(train)=0.50 run_time=212.97s | err(valid)=1.40 acc(valid)=0.52
# End of epoch 03: err(train)=1.34 acc(train)=0.54 run_time=212.80s | err(valid)=1.30 acc(valid)=0.56
# End of epoch 04: err(train)=1.22 acc(train)=0.58 run_time=212.68s | err(valid)=1.22 acc(valid)=0.58
# End of epoch 05: err(train)=1.14 acc(train)=0.61 run_time=213.41s | err(valid)=1.17 acc(valid)=0.60
# End of epoch 06: err(train)=1.08 acc(train)=0.63 run_time=213.54s | err(valid)=1.13 acc(valid)=0.62
# End of epoch 07: err(train)=1.03 acc(train)=0.65 run_time=212.98s | err(valid)=1.11 acc(valid)=0.62
# End of epoch 08: err(train)=0.98 acc(train)=0.66 run_time=215.51s | err(valid)=1.10 acc(valid)=0.62
# End of epoch 09: err(train)=0.94 acc(train)=0.68 run_time=214.67s | err(valid)=1.09 acc(valid)=0.63
# ...

# %%
MSD10_stab_b100_h200=net.Norm_RNN_Model(title='MSD10_basic_b100_h200',num_hidden=200,beta=100,lr=1e-3,num_epochs=40)
MSD10_stab_b100_h200.run_session()
# Out:
# End of epoch 01: err(train)=1.87 acc(train)=0.42 run_time=211.80s | err(valid)=1.59 acc(valid)=0.48
# End of epoch 02: err(train)=1.47 acc(train)=0.50 run_time=213.76s | err(valid)=1.40 acc(valid)=0.52
# End of epoch 03: err(train)=1.33 acc(train)=0.54 run_time=214.87s | err(valid)=1.28 acc(valid)=0.56
# End of epoch 04: err(train)=1.23 acc(train)=0.58 run_time=212.67s | err(valid)=1.24 acc(valid)=0.57
# End of epoch 05: err(train)=1.15 acc(train)=0.61 run_time=213.51s | err(valid)=1.17 acc(valid)=0.60
# End of epoch 06: err(train)=1.09 acc(train)=0.63 run_time=212.52s | err(valid)=1.13 acc(valid)=0.61
# End of epoch 07: err(train)=1.05 acc(train)=0.64 run_time=213.06s | err(valid)=1.13 acc(valid)=0.61
# End of epoch 08: err(train)=1.00 acc(train)=0.66 run_time=212.97s | err(valid)=1.12 acc(valid)=0.61
# End of epoch 09: err(train)=0.96 acc(train)=0.67 run_time=212.53s | err(valid)=1.08 acc(valid)=0.63
# ...

# %%
MSD25_stab_b100_h200=net.Norm_RNN_Model(title='MSD25_basic_b100_h200',num_hidden=200,beta=100,lr=1e-3,num_epochs=40,provider=1)
MSD25_stab_b100_h200.run_session()
# Out:
# End of epoch 01: err(train)=3.01 acc(train)=0.16 run_time=213.31s | err(valid)=2.76 acc(valid)=0.19
# End of epoch 02: err(train)=2.66 acc(train)=0.21 run_time=212.83s | err(valid)=2.60 acc(valid)=0.22
# End of epoch 03: err(train)=2.52 acc(train)=0.24 run_time=213.73s | err(valid)=2.53 acc(valid)=0.23
# End of epoch 04: err(train)=2.44 acc(train)=0.26 run_time=213.69s | err(valid)=2.45 acc(valid)=0.25
# End of epoch 05: err(train)=2.39 acc(train)=0.28 run_time=212.88s | err(valid)=2.44 acc(valid)=0.26
# End of epoch 06: err(train)=2.34 acc(train)=0.29 run_time=213.70s | err(valid)=2.42 acc(valid)=0.26
# End of epoch 07: err(train)=2.30 acc(train)=0.30 run_time=213.92s | err(valid)=2.39 acc(valid)=0.27
# End of epoch 08: err(train)=2.25 acc(train)=0.31 run_time=213.27s | err(valid)=2.36 acc(valid)=0.28
# End of epoch 09: err(train)=2.21 acc(train)=0.32 run_time=214.46s | err(valid)=2.35 acc(valid)=0.28
# ...

# %%
MSD25_stab_b100_h100=net.Norm_RNN_Model(title='MSD25_basic_b100_h100',num_hidden=100,beta=100,lr=1e-3,num_epochs=40,provider=1)
MSD25_stab_b100_h100.run_session()
# Out:
# End of epoch 01: err(train)=3.05 acc(train)=0.15 run_time=110.01s | err(valid)=2.79 acc(valid)=0.18
# End of epoch 02: err(train)=2.70 acc(train)=0.20 run_time=106.36s | err(valid)=2.64 acc(valid)=0.22
# End of epoch 03: err(train)=2.58 acc(train)=0.23 run_time=103.71s | err(valid)=2.57 acc(valid)=0.23
# End of epoch 04: err(train)=2.50 acc(train)=0.25 run_time=103.74s | err(valid)=2.53 acc(valid)=0.23
# End of epoch 05: err(train)=2.44 acc(train)=0.26 run_time=102.79s | err(valid)=2.45 acc(valid)=0.26
# End of epoch 06: err(train)=2.39 acc(train)=0.27 run_time=103.08s | err(valid)=2.42 acc(valid)=0.27
# End of epoch 07: err(train)=2.35 acc(train)=0.29 run_time=103.12s | err(valid)=2.41 acc(valid)=0.26
# End of epoch 08: err(train)=2.32 acc(train)=0.29 run_time=102.94s | err(valid)=2.40 acc(valid)=0.27
# End of epoch 09: err(train)=2.29 acc(train)=0.30 run_time=102.45s | err(valid)=2.40 acc(valid)=0.27
# ...

# %%
MSD25_stab_b50_h100=net.Norm_RNN_Model(title='MSD25_basic_b50_h100',num_hidden=100,beta=50,lr=1e-3,num_epochs=40,provider=1)
MSD25_stab_b50_h100.run_session()
# Out:
# End of epoch 01: err(train)=2.94 acc(train)=0.16 run_time=103.37s | err(valid)=2.76 acc(valid)=0.20
# End of epoch 02: err(train)=2.67 acc(train)=0.21 run_time=103.49s | err(valid)=2.66 acc(valid)=0.21
# End of epoch 03: err(train)=2.56 acc(train)=0.23 run_time=103.43s | err(valid)=2.55 acc(valid)=0.23
# End of epoch 04: err(train)=2.48 acc(train)=0.25 run_time=103.30s | err(valid)=2.50 acc(valid)=0.24
# End of epoch 05: err(train)=2.42 acc(train)=0.27 run_time=103.79s | err(valid)=2.45 acc(valid)=0.25
# End of epoch 06: err(train)=2.38 acc(train)=0.28 run_time=104.53s | err(valid)=2.43 acc(valid)=0.26
# End of epoch 07: err(train)=2.34 acc(train)=0.29 run_time=104.05s | err(valid)=2.45 acc(valid)=0.26
# End of epoch 08: err(train)=2.31 acc(train)=0.30 run_time=104.24s | err(valid)=2.40 acc(valid)=0.27
# End of epoch 09: err(train)=2.28 acc(train)=0.30 run_time=103.13s | err(valid)=2.40 acc(valid)=0.27
# ...

# %%
MSD25_stab_b50_h200=net.Norm_RNN_Model(title='MSD25_basic_b50_h200',num_hidden=200,beta=50,lr=1e-3,num_epochs=40,provider=1)
MSD25_stab_b50_h200.run_session()
# Out:
# End of epoch 01: err(train)=2.95 acc(train)=0.17 run_time=217.01s | err(valid)=2.76 acc(valid)=0.19
# End of epoch 02: err(train)=2.66 acc(train)=0.21 run_time=217.20s | err(valid)=2.61 acc(valid)=0.22
# End of epoch 03: err(train)=2.54 acc(train)=0.24 run_time=216.63s | err(valid)=2.53 acc(valid)=0.23
# End of epoch 04: err(train)=2.44 acc(train)=0.26 run_time=216.14s | err(valid)=2.45 acc(valid)=0.26
# End of epoch 05: err(train)=2.38 acc(train)=0.28 run_time=217.35s | err(valid)=2.43 acc(valid)=0.26
# End of epoch 06: err(train)=2.32 acc(train)=0.29 run_time=216.64s | err(valid)=2.39 acc(valid)=0.27
# End of epoch 07: err(train)=2.27 acc(train)=0.31 run_time=217.79s | err(valid)=2.37 acc(valid)=0.28
# End of epoch 08: err(train)=2.23 acc(train)=0.32 run_time=216.39s | err(valid)=2.36 acc(valid)=0.28
# End of epoch 09: err(train)=2.18 acc(train)=0.33 run_time=217.07s | err(valid)=2.36 acc(valid)=0.28
# ...

# %%
MSD25_stab_b50_h200=net.Norm_RNN_Model(title='MSD25_basic_b0',num_hidden=200,beta=0,lr=1e-3,num_epochs=40,provider=1)
MSD25_stab_b50_h200.run_session()
# Out:
# End of epoch 01: err(train)=2.74 acc(train)=0.18 run_time=219.11s | err(valid)=2.73 acc(valid)=0.17
# End of epoch 02: err(train)=2.59 acc(train)=0.22 run_time=218.43s | err(valid)=2.57 acc(valid)=0.22
# End of epoch 03: err(train)=2.49 acc(train)=0.24 run_time=218.35s | err(valid)=2.53 acc(valid)=0.23
# End of epoch 04: err(train)=2.41 acc(train)=0.27 run_time=216.97s | err(valid)=2.49 acc(valid)=0.24
# End of epoch 05: err(train)=2.33 acc(train)=0.29 run_time=218.70s | err(valid)=2.48 acc(valid)=0.24
# End of epoch 06: err(train)=2.26 acc(train)=0.31 run_time=216.38s | err(valid)=2.46 acc(valid)=0.25
# End of epoch 07: err(train)=2.18 acc(train)=0.33 run_time=217.88s | err(valid)=2.45 acc(valid)=0.25
# End of epoch 08: err(train)=2.10 acc(train)=0.35 run_time=216.50s | err(valid)=2.47 acc(valid)=0.26
# End of epoch 09: err(train)=2.01 acc(train)=0.37 run_time=218.05s | err(valid)=2.50 acc(valid)=0.25
# ...

# %%
MSD25_basic_lam4=net.RNN_Model(title='MSD25_basic_lam4',num_hidden=200,lam=1e-4,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic_lam4.run_session()
MSD25_basic_lam3=net.RNN_Model(title='MSD25_basic_lam3',num_hidden=200,lam=1e-3,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic_lam3.run_session()
# Out:
# End of epoch 01: err(train)=2.81 acc(train)=0.17 run_time=185.70s | err(valid)=2.75 acc(valid)=0.18
# End of epoch 02: err(train)=2.68 acc(train)=0.21 run_time=186.32s | err(valid)=2.70 acc(valid)=0.20
# End of epoch 03: err(train)=2.59 acc(train)=0.23 run_time=185.85s | err(valid)=2.63 acc(valid)=0.22
# End of epoch 04: err(train)=2.51 acc(train)=0.26 run_time=184.83s | err(valid)=2.59 acc(valid)=0.24
# End of epoch 05: err(train)=2.45 acc(train)=0.27 run_time=184.53s | err(valid)=2.55 acc(valid)=0.25
# End of epoch 06: err(train)=2.39 acc(train)=0.29 run_time=184.94s | err(valid)=2.53 acc(valid)=0.25
# End of epoch 07: err(train)=2.32 acc(train)=0.31 run_time=185.34s | err(valid)=2.53 acc(valid)=0.25
# End of epoch 08: err(train)=2.26 acc(train)=0.33 run_time=184.72s | err(valid)=2.53 acc(valid)=0.26
# End of epoch 09: err(train)=2.20 acc(train)=0.35 run_time=184.20s | err(valid)=2.57 acc(valid)=0.26
# ...

# %%
MSD10_basic_lam4_h100=net.RNN_Model(title='MSD10_basic_lam4_h100',num_hidden=100,lam=1e-4,lr=1e-3,num_epochs=40)
MSD10_basic_lam4_h100.run_session()
MSD10_basic_lam3_h100=net.RNN_Model(title='MSD10_basic_lam3_h_100',num_hidden=100,lam=1e-3,lr=1e-3,num_epochs=40)
MSD10_basic_lam3_h100.run_session()
# Out:
# End of epoch 01: err(train)=1.65 acc(train)=0.43 run_time=95.00s | err(valid)=1.54 acc(valid)=0.46
# End of epoch 02: err(train)=1.47 acc(train)=0.49 run_time=94.44s | err(valid)=1.45 acc(valid)=0.50
# End of epoch 03: err(train)=1.37 acc(train)=0.53 run_time=93.31s | err(valid)=1.39 acc(valid)=0.53
# End of epoch 04: err(train)=1.30 acc(train)=0.56 run_time=92.63s | err(valid)=1.34 acc(valid)=0.55
# End of epoch 05: err(train)=1.23 acc(train)=0.59 run_time=92.91s | err(valid)=1.31 acc(valid)=0.57
# End of epoch 06: err(train)=1.19 acc(train)=0.60 run_time=92.75s | err(valid)=1.26 acc(valid)=0.58
# End of epoch 07: err(train)=1.14 acc(train)=0.62 run_time=92.62s | err(valid)=1.26 acc(valid)=0.58
# End of epoch 08: err(train)=1.10 acc(train)=0.63 run_time=92.30s | err(valid)=1.26 acc(valid)=0.59
# End of epoch 09: err(train)=1.07 acc(train)=0.65 run_time=92.26s | err(valid)=1.24 acc(valid)=0.60
# ...

# %%
MSD25_basic_lam4_h100=net.RNN_Model(title='MSD25_basic_lam4_h100',num_hidden=100,lam=1e-4,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic_lam4_h100.run_session()
# Out:
# End of epoch 01: err(train)=2.79 acc(train)=0.17 run_time=93.46s | err(valid)=2.73 acc(valid)=0.19
# End of epoch 02: err(train)=2.65 acc(train)=0.21 run_time=93.17s | err(valid)=2.65 acc(valid)=0.20
# End of epoch 03: err(train)=2.58 acc(train)=0.23 run_time=92.88s | err(valid)=2.61 acc(valid)=0.22
# End of epoch 04: err(train)=2.54 acc(train)=0.24 run_time=92.75s | err(valid)=2.59 acc(valid)=0.23
# End of epoch 05: err(train)=2.49 acc(train)=0.26 run_time=92.27s | err(valid)=2.57 acc(valid)=0.23
# End of epoch 06: err(train)=2.44 acc(train)=0.27 run_time=92.32s | err(valid)=2.53 acc(valid)=0.24
# End of epoch 07: err(train)=2.39 acc(train)=0.28 run_time=92.33s | err(valid)=2.52 acc(valid)=0.24
# End of epoch 08: err(train)=2.36 acc(train)=0.29 run_time=92.41s | err(valid)=2.50 acc(valid)=0.25
# End of epoch 09: err(train)=2.33 acc(train)=0.30 run_time=92.73s | err(valid)=2.50 acc(valid)=0.25
# ...

# %%
MSD25_basic_lam3_h100=net.RNN_Model(title='MSD25_basic_lam3_h100',num_hidden=100,lam=1e-3,lr=1e-3,num_epochs=40,provider=1)
MSD25_basic_lam3_h100.run_session()
# Out:
# End of epoch 01: err(train)=2.99 acc(train)=0.17 run_time=93.51s | err(valid)=2.87 acc(valid)=0.20
# End of epoch 02: err(train)=2.81 acc(train)=0.20 run_time=93.29s | err(valid)=2.81 acc(valid)=0.21
# End of epoch 03: err(train)=2.73 acc(train)=0.22 run_time=93.30s | err(valid)=2.76 acc(valid)=0.21
# End of epoch 04: err(train)=2.68 acc(train)=0.23 run_time=92.91s | err(valid)=2.68 acc(valid)=0.23
# End of epoch 05: err(train)=2.64 acc(train)=0.24 run_time=93.00s | err(valid)=2.66 acc(valid)=0.24
# End of epoch 06: err(train)=2.60 acc(train)=0.25 run_time=92.65s | err(valid)=2.64 acc(valid)=0.24
# End of epoch 07: err(train)=2.58 acc(train)=0.26 run_time=92.31s | err(valid)=2.63 acc(valid)=0.24
# End of epoch 08: err(train)=2.57 acc(train)=0.26 run_time=92.48s | err(valid)=2.62 acc(valid)=0.25
# End of epoch 09: err(train)=2.54 acc(train)=0.27 run_time=92.24s | err(valid)=2.62 acc(valid)=0.25
# ...

# %%
MSD25_auto_a20 = net.MultiAuto_RNN_Model(title='MSD25_auto_a20',num_hidden=100,beta=100,lr=1e-3,num_epochs=40,provider=1,alpha=2)

# %%
MSD25_auto_a20.run_session()
# Out:
# End of epoch 01: err(tr)=3.09 acc(train)=0.16 err2=0.88 run_time=114.98s | err(v)=2.80 acc(valid)=0.19
# End of epoch 02: err(tr)=2.69 acc(train)=0.21 err2=0.82 run_time=114.47s | err(v)=2.64 acc(valid)=0.22
# End of epoch 03: err(tr)=2.57 acc(train)=0.23 err2=0.80 run_time=114.30s | err(v)=2.55 acc(valid)=0.24
# End of epoch 04: err(tr)=2.49 acc(train)=0.25 err2=0.79 run_time=114.06s | err(v)=2.50 acc(valid)=0.25
# End of epoch 05: err(tr)=2.43 acc(train)=0.27 err2=0.78 run_time=113.93s | err(v)=2.49 acc(valid)=0.25
# End of epoch 06: err(tr)=2.38 acc(train)=0.28 err2=0.77 run_time=113.81s | err(v)=2.41 acc(valid)=0.27
# End of epoch 07: err(tr)=2.35 acc(train)=0.29 err2=0.76 run_time=113.69s | err(v)=2.40 acc(valid)=0.27
# End of epoch 08: err(tr)=2.31 acc(train)=0.30 err2=0.76 run_time=113.67s | err(v)=2.38 acc(valid)=0.27
# End of epoch 09: err(tr)=2.29 acc(train)=0.30 err2=0.75 run_time=113.65s | err(v)=2.36 acc(valid)=0.28
# ...

# %%
MSD25_auto_a10 = net.MultiAuto_RNN_Model(title='MSD25_auto_a10',num_hidden=100,beta=100,lr=1e-3,num_epochs=30,provider=1,alpha=1)

# %%
MSD25_auto_a10.run_session()
# Out:
# End of epoch 01: err(tr)=3.12 acc(train)=0.15 err2=0.89 run_time=115.61s | err(v)=2.85 acc(valid)=0.17
# End of epoch 02: err(tr)=2.72 acc(train)=0.20 err2=0.84 run_time=114.46s | err(v)=2.67 acc(valid)=0.21
# End of epoch 03: err(tr)=2.59 acc(train)=0.23 err2=0.82 run_time=114.51s | err(v)=2.56 acc(valid)=0.23
# End of epoch 04: err(tr)=2.50 acc(train)=0.25 err2=0.81 run_time=114.38s | err(v)=2.51 acc(valid)=0.24
# End of epoch 05: err(tr)=2.45 acc(train)=0.26 err2=0.80 run_time=114.32s | err(v)=2.47 acc(valid)=0.26
# End of epoch 06: err(tr)=2.40 acc(train)=0.27 err2=0.79 run_time=114.66s | err(v)=2.43 acc(valid)=0.27
# End of epoch 07: err(tr)=2.36 acc(train)=0.29 err2=0.79 run_time=114.43s | err(v)=2.41 acc(valid)=0.27
# End of epoch 08: err(tr)=2.33 acc(train)=0.29 err2=0.78 run_time=114.35s | err(v)=2.39 acc(valid)=0.27
# End of epoch 09: err(tr)=2.30 acc(train)=0.30 err2=0.78 run_time=114.03s | err(v)=2.39 acc(valid)=0.27
# ...

# %%
MSD10_auto_a10 = net.MultiAuto_RNN_Model(title='MSD10_auto_a10',num_hidden=100,beta=100,lr=1e-3,num_epochs=30,alpha=1)

# %%
MSD10_auto_a10.run_session()
# Out:
# End of epoch 01: err(tr)=1.92 acc(train)=0.42 err2=0.88 run_time=115.01s | err(v)=1.61 acc(valid)=0.48
# End of epoch 02: err(tr)=1.53 acc(train)=0.49 err2=0.85 run_time=113.01s | err(v)=1.48 acc(valid)=0.51
# End of epoch 03: err(tr)=1.41 acc(train)=0.53 err2=0.83 run_time=112.06s | err(v)=1.39 acc(valid)=0.54
# End of epoch 04: err(tr)=1.32 acc(train)=0.56 err2=0.82 run_time=111.42s | err(v)=1.33 acc(valid)=0.55
# End of epoch 05: err(tr)=1.24 acc(train)=0.58 err2=0.81 run_time=111.53s | err(v)=1.24 acc(valid)=0.58
# End of epoch 06: err(tr)=1.19 acc(train)=0.60 err2=0.81 run_time=111.78s | err(v)=1.23 acc(valid)=0.58
# End of epoch 07: err(tr)=1.14 acc(train)=0.61 err2=0.80 run_time=112.24s | err(v)=1.20 acc(valid)=0.60
# End of epoch 08: err(tr)=1.11 acc(train)=0.62 err2=0.80 run_time=112.82s | err(v)=1.13 acc(valid)=0.61
# End of epoch 09: err(tr)=1.08 acc(train)=0.63 err2=0.79 run_time=113.35s | err(v)=1.12 acc(valid)=0.62
# ...

# %%
MSD10_auto_a20 = net.MultiAuto_RNN_Model(title='MSD10_auto_a20',num_hidden=100,beta=100,lr=1e-3,num_epochs=30,alpha=1)

# %%
MSD10_auto_a20.run_session()

# %%
MSD10_class = net.MultiClass_RNN_Model(title='MSD10_class',num_hidden=100,beta=100,lr=1e-3,num_epochs=30,alpha=1)

# %%
MSD10_class.run_session()

# %%
MSD10_class_a20 = net.MultiClass_RNN_Model(title='MSD10_class_a20',num_hidden=100,beta=100,lr=1e-3,num_epochs=30,alpha=2)

# %%
MSD10_class_a20.run_session()

# %%
MSD25_class_a20 = net.MultiClass_RNN_Model(title='MSD25_class_a20',num_hidden=200,beta=100,lr=1e-3,num_epochs=30,alpha=2,provider=1)

# %%
MSD25_class_a20.run_session()

# %%
MSD25_class = net.MultiClass_RNN_Model(title='MSD25_class',num_hidden=200,beta=100,lr=1e-3,num_epochs=30,alpha=1,provider=1)

# %%
MSD25_class.run_session()

# %%
MSD10_ens_d4 = net.Ens_RNN_Model(title='MSD10_ens_d4',num_hidden=400,beta=100,lr=1e-3,num_epochs=40,div=4)

# %%
MSD10_ens_d4.run_session()
# Out:
# End of epoch 01: err(train)=1.81 acc(train)=0.44 run_time=134.66s | err(valid)=1.68 acc(valid)=0.49
# End of epoch 02: err(train)=1.62 acc(train)=0.52 run_time=131.11s | err(valid)=1.59 acc(valid)=0.53
# End of epoch 03: err(train)=1.54 acc(train)=0.55 run_time=128.42s | err(valid)=1.52 acc(valid)=0.55
# End of epoch 04: err(train)=1.48 acc(train)=0.57 run_time=128.92s | err(valid)=1.49 acc(valid)=0.57
# End of epoch 05: err(train)=1.44 acc(train)=0.59 run_time=128.57s | err(valid)=1.44 acc(valid)=0.58
# End of epoch 06: err(train)=1.40 acc(train)=0.61 run_time=129.07s | err(valid)=1.41 acc(valid)=0.59
# End of epoch 07: err(train)=1.36 acc(train)=0.62 run_time=127.95s | err(valid)=1.39 acc(valid)=0.60
# End of epoch 08: err(train)=1.33 acc(train)=0.63 run_time=127.94s | err(valid)=1.37 acc(valid)=0.60
# End of epoch 09: err(train)=1.31 acc(train)=0.65 run_time=127.88s | err(valid)=1.37 acc(valid)=0.61
# ...

# %%
MSD10_ens_d4_m1 = net.Ens_RNN_Model(title='MSD10_ens_d4_m1',num_hidden=400,beta=100,lr=1e-3,num_epochs=40,div=4,method=1)

# %%
MSD10_ens_d4_m1.run_session()

# %%
MSD10_ens_d2_m1 = net.Ens_RNN_Model(title='MSD10_ens_d2_m1',num_hidden=200,beta=100,lr=1e-3,num_epochs=40,div=2,method=1)

# %%
MSD10_ens_d2_m1.run_session()

# %%
MSD10_ens_d2 = net.Ens_RNN_Model(title='MSD10_ens_d2',num_hidden=200,beta=100,lr=1e-3,num_epochs=40,div=2)

# %%
MSD10_ens_d2.run_session()

# %%
MSD25_ens_d2 = net.Ens_RNN_Model(title='MSD25_ens_d2',num_hidden=200,beta=100,lr=1e-3,num_epochs=40,div=2,provider=1)

# %%
MSD25_ens_d2.run_session()

# %%
MSD25_ens_d4 = net.Ens_RNN_Model(title='MSD25_ens_d4',num_hidden=200,beta=100,lr=1e-3,num_epochs=40,div=4,provider=1)

# %%
MSD25_ens_d4.run_session()

# %%
MSD25_ens_d4_m1 = net.Ens_RNN_Model(title='MSD25_ens_d4_m1',num_hidden=200,beta=100,lr=1e-3,num_epochs=40,div=4,provider=1,method=1)

# %%
MSD25_ens_d4_m1.run_session()

# %%
MSD10_exp = net.EnsL_RNN_Model(title='MSD10_exp',num_hidden=200,lr=1e-3,num_epochs=40,beta=100,div=2)
# Out:
# 2

# %%
MSD10_exp.run_session()
# Out:
# End of epoch 01: err(train)=1.54 acc(train)=0.45 run_time=109.67s | err(valid)=1.38 acc(valid)=0.51
# End of epoch 02: err(train)=1.31 acc(train)=0.53 run_time=102.75s | err(valid)=1.34 acc(valid)=0.53
# End of epoch 03: err(train)=1.21 acc(train)=0.57 run_time=108.03s | err(valid)=1.21 acc(valid)=0.57
# End of epoch 04: err(train)=1.15 acc(train)=0.60 run_time=101.53s | err(valid)=1.18 acc(valid)=0.58
# End of epoch 05: err(train)=1.10 acc(train)=0.61 run_time=101.65s | err(valid)=1.16 acc(valid)=0.59
# End of epoch 06: err(train)=1.06 acc(train)=0.63 run_time=102.89s | err(valid)=1.14 acc(valid)=0.60
# End of epoch 07: err(train)=1.03 acc(train)=0.64 run_time=104.21s | err(valid)=1.13 acc(valid)=0.61
# End of epoch 08: err(train)=1.01 acc(train)=0.65 run_time=104.77s | err(valid)=1.10 acc(valid)=0.62
# End of epoch 09: err(train)=0.98 acc(train)=0.66 run_time=103.45s | err(valid)=1.09 acc(valid)=0.62
# ...
