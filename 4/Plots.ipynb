# %%
import rnn_networks as net
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
t11=np.load("MSD10_ens_d2.npy")

# %%
t12=np.load("MSD10_ens_d2_m1.npy")

# %%
t21=np.load("MSD10_ens_d4.npy")

# %%
t22=np.load("MSD10_ens_d4_m1.npy")

# %%
sims = [[t11,t12],[t21,t22]]

# %%
test = net.MultiPlot(sims,labels=[r'$m$','snippets'])

# %%
test.acc_curves([["d2_m0","d2_m1"],["d4_m0","d4_m1"]])

# %%
test.acc_heat([2,4],[0,1])

# %%
test.time_heat([2,4],[0,1])

# %%
t11=np.load("MSD25_ens_d2.npy")

# %%
t12=np.load("MSD25_ens_d2_m1.npy")

# %%
t21=np.load("MSD25_ens_d4.npy")

# %%
t22=np.load("MSD25_ens_d4_m1.npy")

# %%
sims = [[t11,t12],[t21,t22]]

# %%
test = net.MultiPlot(sims,labels=[r'$m$','snippets'])

# %%
test.acc_curves([["lam4_h100","lam4_h200"],["lam3_h100","lam3_h200"]])

# %%
test.acc_heat([2,4],[0,1])

# %%
t11=np.load("MSD25_auto_a10.npy")[:,:30]

# %%
t12=np.load("MSD25_auto_a20.npy")[:,:30]

# %%
t21=np.load("MSD25_class.npy")[:,:30]

# %%
t22=np.load("MSD25_class_a20.npy")[:,:30]

# %%
sims = [[t11,t12],[t21,t22]]

# %%
test = net.MultiPlot(sims,labels=[r'$\alpha$','type'])

# %%
test.err2_curves([["auto_a1","auto_a2"],["class_a1","class_a2"]])

# %%
test.acc_heat(['auto','class'],[1,2])

# %%
test.time_heat(['auto','class'],[1,2])

# %%
t11=np.load("MSD10_auto_a10.npy")[:,:30]

# %%
t12=np.load("MSD10_auto_a20.npy")[:,:30]

# %%
t21=np.load("MSD10_class.npy")[:,:30]

# %%
t22=np.load("MSD10_class_a20.npy")[:,:30]

# %%
sims = [[t11,t12],[t21,t22]]

# %%
test = net.MultiPlot(sims,labels=[r'$\alpha$','type'])

# %%
test.err_curves([["auto_a1","auto_a2"],["class_a1","class_a2"]])

# %%
test.acc_heat(['auto','class'],[1,2])

# %%
t11=np.load("MSD25_basic_lam3_h100.npy")

# %%
t22=np.load("MSD25_basic_b100_h100.npy")

# %%
sims = [[t11],[t22]]

# %%
test = net.MultiPlot(sims,labels=['lam','bet'])

# %%
test.acc_curves([["lam3_h100"],["b100_h100"]])

# %%
test.d1
# Out:
# 1

# %%
test.d2
# Out:
# 1

# %%
len(sims)
# Out:
# 2

# %%
targets = np.load('targets.npy')

# %%
len(targets)
# Out:
# 9991
